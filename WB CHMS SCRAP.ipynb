# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC 
from selenium.webdriver.support.ui import WebDriverWait
import os,time,re,math
from selenium.common.exceptions import StaleElementReferenceException

# %%
# Pre-processed datas to match with current backend system
using_district_list = {
    "ALIPURDUAR": 719,
    "BANKURA": 720,
    "BIRBHUM": 721,
    "COOCHBEHAR": 722,
    "DAKSHIN 24 PARGANA": 740,
    "DAKSHIN DINAJPUR": 723,
    "DARJEELING": 724,
    "HOOGHLY": 725,
    "HOWRAH": 726,
    "JALPAIGURI": 727,
    "JHARGRAM": 728,
    "KALIMPONG": 729,
    "KOLKATA METROPOLITAN AREA": 730,
    "MALDA": 731,
    "MURSHIDABAD": 732,
    "NADIA": 733,
    "PASCHIM BARDHAMAN": 735,
    "PASCHIM MEDINIPUR": 736,
    "PURBA BARDHHAMAN": 737,
    "PURBA MEDINIPUR": 738,
    "PURULIA": 739,
    "UTTAR 24 PARGANA": 734,
    "UTTAR DINAJPUR": 741
}

using_hospital_type={
    "Government Hospital": {
        "dbkey": "govt",
        "webkey": 1
    },
    "Govt. Requisitioned Pvt. Hospital": {
        "dbkey": "pvtundergovt",
        "webkey": 2
    },
    "Private Hospital": {
        "dbkey": "private",
        "webkey": 3
    }
}

# Config
PATH_TO_DRIVER = r'/usr/bin/chromedriver'
endpoint = 'https://excise.wb.gov.in/CHMS/Public/Page/CHMS_Public_Hospital_Bed_Availability.aspx'


chrome_options = Options()
# chrome_options.add_argument("--headless")
# chrome_options.add_argument("--window-size=1920x1080")


#Functions

#Init
def init_scrape(chrome_options,endpoint,PATH_TO_DRIVER=r'/usr/bin/chromedriver'):
    driver = webdriver.Chrome(executable_path = PATH_TO_DRIVER, options=chrome_options)
    driver.get(endpoint)
    wait = WebDriverWait(driver,30)
    wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_ddl_District")))
    return driver,wait

# Track the loading spinner
def still_loading(driver,wait):
    try:
        return driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_upPgo"]').value_of_css_property("display")
    except:
        return "done"
    
    
# Select Radio Buttons
def select_hospital_type(driver,label):
    try:
        radio = driver.find_element_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_rdo_Govt_Flag']/label[{}]".format(str(label)))
        radio.click()
        driver.implicitly_wait(10)
    except:
        raise Exception("ERROR : Can't Select Hospital Type")
        
        
# Click on <DISTRICT_NAME> district and load the pages
def select_district_and_wait_until_load(driver,wait,district_name):
    try:
        driver.find_element_by_xpath("//select[@name='ctl00$ContentPlaceHolder1$ddl_District']/option[text()='{}']".format(district_name)).click()
        while still_loading(driver,wait) != "none":
            driver.implicitly_wait(2)
        driver.implicitly_wait(5)
        wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_GridView2")))
    except:
        raise Exception("ERROR : Can't select district")
        

# Get no of pages (Pagination) for selected district
def no_of_pages_for_selected_district_and_type(driver):
    try:
        pages=len(driver.find_elements_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_GridView2']/tbody/tr[1]/td/table/tbody/tr/td"))
        if pages == 0:
            pages = 1
        return pages
    except:
        raise Exception("ERROR : Can't get number of pages for selected district and type")
        
# Select page
def select_page_pagination_section(driver,page_no):
    try:
        driver.find_element_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_GridView2']/tbody/tr[1]/td/table/tbody/tr/td[{}]/a".format(str(page_no))).click()
        while still_loading(driver,wait) != "none":
            driver.implicitly_wait(2)
        driver.implicitly_wait(2)
        wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_GridView2")))
    except:
        raise Exception("ERROR : Switching page for pagination")
        
def try_to_switch_to_first_page(driver):
    try:
        driver.find_element_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_GridView2']/tbody/tr[1]/td/table/tbody/tr/td[{}]/a".format(str(1))).click()
        while still_loading(driver,wait) != "none":
            driver.implicitly_wait(2)
        driver.implicitly_wait(2)
        wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_GridView2")))
    except:
        print("ERROR : Maybe first page is already selected !")
        
# Click on all the "View Detailed break up option"
def toggle_detailed_break_up_section(driver):
    try:
        driver.find_element_by_xpath("//*[contains(@id,'_div_card')]/div[2]/div[2]/div[1]/a").click()
        driver.implicitly_wait(5)
    except:
        raise Exception("ERROR : Can't open detailed break up section")

        
def MobileCleanData(data):
    # Process data for DB
    # Database only have Big Integer field , String not accepted
    result = []
    copydata = None
    # Split data at "/" & "," for multiple mobile number
    if "/" in str(data):
        copydata = str(data).split("/")
    elif "," in str(data):
        copydata = str(data).split(",")
    else:
        copydata = [data]

    for item in copydata:
        try:
            # Remove "+"
            # Remove "(" & ")"
            # Remove "-"
            # Remove all blank spaces
            tmp = item.replace("+","").replace("(","").replace(")","").replace("-","").replace(" ","") 
            
            # Check whether its is empty or not before typecasting to int to reduce possibility of error
            if tmp.strip() != "":
                result.append(int(tmp))
        
        except ValueError:
            print(f"{item} failed")
            return 0,[0]
    # Will return a tupple of (<No of mobile numbers>, [list of <mobileno>])
    return len(result),result


scraping  = False

# Main Driver function for scraping
def scrape_data(driver):
    scraping = True

    # Get the list of hospotals entry
    entries = driver.find_elements_by_xpath("//*[contains(@id,'_div_card')]")
    
    if len(entries) == 0 :
        print("No items found")
        scraping = False
        return
    
    toggle_detailed_break_up_section(driver)

    
    # No of hospitals under selected category and dsitrct
    print(str(len(entries)) + " items fetched.")

    # Iterate through the entried and print the details
    for ei,e in enumerate(entries):
        
    #     print(ei)
        print("Name : {}".format(e.find_element_by_xpath(".//h5").text))
        print("Address : {}".format(e.find_element_by_xpath("(.//div/div/div)[1]").text))
        print("Phoneno : {}".format(MobileCleanData(e.find_element_by_xpath("(.//div/div/div)[2]//a").text)[1][0]))
        print("Total Beds : {}".format(e.find_element_by_xpath(".//div[2]/div[1]/div[4]/div/ul/li[1]/h3").text))
        print("Available Beds : {}".format(e.find_element_by_xpath(".//div[2]/div[1]/div[4]/div/ul/li[2]/h3").text))
        print("Verified On : {}".format(e.find_element_by_xpath(".//div[3]/small").text))
        print("------------------------")
        bed_categories = e.find_elements_by_xpath(".//div[2]/div[2]/div[2]/div/div")
        print("Categories of beds : {}".format(len(bed_categories)))
        for bc in bed_categories:
            # Make sure you have click on "View detailed Details" else you will get blank details
            try:
                print("Category : {}".format(bc.find_element_by_xpath(".//div/div[1]").text))
                print("Available : {}".format(bc.find_element_by_xpath(".//div/div[2]/div/div[4]/div/ul/li[2]/h3").text))
                print("Total : {}".format(bc.find_element_by_xpath(".//div/div[2]/div/div[4]/div/ul/li[1]/h3").text))
            except:
                print("Due to error skipping the category section")
            print("----category_ end-------\n")
            
        print("----------END------------")
    scraping = False

def still_loading(driver,wait):
    try:
        return driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_upPgo"]').value_of_css_property("display")
    except:
        return "error"

# %%
# List of districts
# district_list = driver.find_element_by_id("ctl00_ContentPlaceHolder1_ddl_District")
# final_district_list = []
# for i in district_list.text.split("\n")[1:-1]:
#     final_district_list.append(i.strip())

# %%
# Options Radio Buttons
# RADIO_BUTTONS = driver.find_elements_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_rdo_Govt_Flag']/label")
# for i,j in enumerate(RADIO_BUTTONS):
#     print(j.text,i)

# %% [markdown]
# ## Test Code

# %% [markdown]
# ### Steps one-by-one
# * Call initialize Function > init_scrape
# * First select the hospital type > select_hospital_type
# * Then select district > select_district_and_wait_until_load
# * Get page no > no_of_pages_for_selected_district_and_type
# * Iterate through Pages
#     * Call this function > toggle_detailed_break_up_section
#     * Call scrape data to start scraping > scrape_data

# %%
driver,wait = init_scrape(chrome_options,endpoint)

# %%
for district_lable,district_id in using_district_list.items():
#     print(district_lable,district_id)
    for hospital_type in using_hospital_type:
        select_hospital_type(driver,using_hospital_type[hospital_type]["webkey"])
        select_district_and_wait_until_load(driver,wait,district_lable)
        time.sleep(5)
        no_of_pages = no_of_pages_for_selected_district_and_type(driver)
        print(f"\n\n{no_of_pages}\n\n")
        global_buggy_pnum = 0
        for pg_no in range(no_of_pages):
            if pg_no == 0:
                try_to_switch_to_first_page(driver)
                time.sleep(10)
            if pg_no != 0 or (pg_no==0 and global_buggy_pnum!=0) :
                while True:
                    if scraping:
                        time.sleep(2)
                    else:
                        global_buggy_pnum = pg_no
                        select_page_pagination_section(driver,pg_no+1)
                        time.sleep(10)
                        break
            
            while still_loading(driver,wait) != "none":
                driver.implicitly_wait(10)
            scrape_data(driver)
        print(f"Exiting from District : {district_lable} Type : {hospital_type} Page No : {pg_no}")
# Out:
# 2
#
#
# ERROR : Maybe first page is already selected !
# 10 items fetched.
# Name :  AMRI, Salt Lake - Vivekananda Yuba Bharati Krirangan Salt Lake Stadium (Satellite Govt. Building)
# Address :   JB Block, Sector III, Bidhannagar, Kolkata, West Bengal 700098 , KOLKATA METROPOLITAN AREA
# Phoneno : 9163645544
# Total Beds : 80
# Available Beds : 41
# Verified On : Last Updated On : 13/05/2021 11:09 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 41
# Total : 80
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  CHITTARANJAN NATIONAL CANCER INSTITUTE-CNCI (Government Hospital)
# Address :   Street Number 299, DJ Block(Newtown), Action Area I, Newtown, New Town, West Bengal 700156 , KOLKATA METROPOLITAN AREA
# Phoneno : 33247655102
# Total Beds : 422
# Available Beds : 63
# Verified On : Last Updated On : 13/05/2021 12:05 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 26
# Total : 100
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 20
# Total : 177
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 17
# Total : 145
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  College of Medicine Sagore Dutta Hospital (Government Hospital)
# Address :   578 Barrackpore Trunk Road KAMARHATI Kolkata-700058 , KOLKATA METROPOLITAN AREA
# Phoneno : 3325531316
# Total Beds : 278
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:24 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 160
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 100
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 18
# ----category_ end-------
#
# ----------END------------
# Name :  ESI Hospital Maniktala (Government Hospital)
# Address :   54 Bagmari Road, Kolkata 54 , KOLKATA METROPOLITAN AREA
# Phoneno : 9831795046
# Total Beds : 100
# Available Beds : 6
# Verified On : Last Updated On : 13/05/2021 04:09 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 5
# Total : 36
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 64
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  ESI Hospital Sealdah (Government Hospital)
# Address :   Sealdah , KOLKATA METROPOLITAN AREA
# Phoneno : 9051801907
# Total Beds : 100
# Available Beds : 60
# Verified On : Last Updated On : 13/05/2021 04:16 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 42
# Total : 60
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 18
# Total : 40
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  I.D. And B.G. Hospital (Government Hospital)
# Address :   57, Beleghata Main Rd, Subhas Sarobar Park, Phool Bagan, Beleghata, Kolkata, West Bengal 700010 , KOLKATA METROPOLITAN AREA
# Phoneno : 3323032200
# Total Beds : 315
# Available Beds : 25
# Verified On : Last Updated On : 13/05/2021 10:57 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 16
# Total : 232
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 9
# Total : 50
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 31
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# ----------END------------
# Name :  M R Bangur Hospital (Government Hospital)
# Address :   241, Deshpran Sasmal Rd, Netajinagar, Rajendra Prasad Colony, Tollygunge, Kolkata, West Bengal 700033 , KOLKATA METROPOLITAN AREA
# Phoneno : 8820702070
# Total Beds : 587
# Available Beds : 2
# Verified On : Last Updated On : 13/05/2021 12:09 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 1
# Total : 33
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 261
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 215
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 78
# ----category_ end-------
#
# ----------END------------
# Name :  Medical College and Hospital, Kolkata, (Government Hospital)
# Address :   88, College St, Calcutta Medical College, College Square, Kolkata, West Bengal 700073 , KOLKATA METROPOLITAN AREA
# Phoneno : 3322551614
# Total Beds : 411
# Available Beds : 12
# Verified On : Last Updated On : 13/05/2021 10:16 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 12
# Total : 343
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 43
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 25
# ----category_ end-------
#
# ----------END------------
# Name :  Nil Ratan Sarkar Medical College and Hospital (Government Hospital)
# Address :   138, Acharya Jagadish Chandra Bose Rd, Sealdah, Raja Bazar, Kolkata, West Bengal 700014 , KOLKATA METROPOLITAN AREA
# Phoneno : 3322860033
# Total Beds : 180
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 10:21 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 129
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 47
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 4
# ----category_ end-------
#
# ----------END------------
# Name :  R. G. Kar Medical College and Hospital (Government Hospital)
# Address :   1, Khudiram Bose Sarani, Bidhan Sarani, Shyam Bazar, Kolkata, West Bengal 700004 , KOLKATA METROPOLITAN AREA
# Phoneno : 3325304557
# Total Beds : 300
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 07:50 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 280
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# 1 items fetched.
# Name :  Sambhunath Pandit Hospital (Government Hospital)
# Address :   11, Elgin Rd, Sreepally, Bhowanipore, Kolkata, West Bengal 700020 , KOLKATA METROPOLITAN AREA
# Phoneno : 3323022820
# Total Beds : 166
# Available Beds : 16
# Verified On : Last Updated On : 13/05/2021 12:43 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 16
# Total : 59
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 72
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 16
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 13
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# ----------END------------
# Exiting from District : KOLKATA METROPOLITAN AREA Type : Government Hospital Page No : 1
#
#
# 2
#
#
# 10 items fetched.
# Name :  AMRI HOSPITAL, SALT LAKE Govt Requisitioned (Govt. Requisitioned Pvt. Hospital)
# Address :   16 17, JC Block Lane, Central Park Road Broadway Road, stadium gate number 3, opposite salt lake, Sector III, Bidhannagar, Kolkata, West Bengal 700098 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366063800
# Total Beds : 25
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 11:03 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 25
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Belle Vue Clinic, Govt Requisitioned (Govt. Requisitioned Pvt. Hospital)
# Address :   9, Dr. U. N. Brahmachari Street (Formerly Loudon Street), Elgin, Kolkata, West Bengal 700017 , KOLKATA METROPOLITAN AREA
# Phoneno : 9331847265
# Total Beds : 236
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:45 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 190
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 32
# ----category_ end-------
#
# ----------END------------
# Name :  Charnock Hospital Govt. Requisitioned (Govt. Requisitioned Pvt. Hospital)
# Address :   BMC , Biswa Bangla Sarani, Tegharia, Newtown, Kolkata, West Bengal 700157 , KOLKATA METROPOLITAN AREA
# Phoneno : 9831539000
# Total Beds : 25
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 12:40 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 13
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# ----------END------------
# Name :  Dafodil Nursing Home Govt. Requisitioned (Govt. Requisitioned Pvt. Hospital)
# Address :   No. 276, Canal St, Sreebhumi, Lake Town, Kolkata, West Bengal 700048 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340505555
# Total Beds : 11
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 10:44 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 1
# Total : 10
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 1
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  DESUN Hospital (Govt. Requisitioned Pvt. Hospital)
# Address :   Desun More, 720, Eastern Metropolitan Bypass, Golpark, Sector I, Kasba, Kolkata, West Bengal 700107 , KOLKATA METROPOLITAN AREA
# Phoneno : 9051715171
# Total Beds : 25
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 09:16 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 17
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Name :  DESUN Hospital Category Govt. Requisitioned Pvt. Hospital (Govt. Requisitioned Pvt. Hospital)
# Address :   Desun More, , Eastern Metropolitan Bypass, Golpark, Sector I, Kasba, Kolkata, West Bengal , KOLKATA METROPOLITAN AREA
# Phoneno : 9051715171
# Total Beds : 135
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 09:29 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 80
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 28
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 27
# ----category_ end-------
#
# ----------END------------
# Name :  Fortis Hospital Anandapur Category Private Hospital Govt. Requisitioned (Govt. Requisitioned Pvt. Hospital)
# Address :   Eastern Metropolitan Bypass, Anandapur, East Kolkata Twp, Kolkata, West Bengal , KOLKATA METROPOLITAN AREA
# Phoneno : 3366284646
# Total Beds : 25
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 02:31 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  ILS Hospitals, Dumdum Govt. Requisitioned Pvt. Hospital (Govt. Requisitioned Pvt. Hospital)
# Address :   Mall Road, near Nager Bazar Flyover, Dum Dum, Kolkata, West Bengal , KOLKATA METROPOLITAN AREA
# Phoneno : 3340315041
# Total Beds : 21
# Available Beds : 13
# Verified On : Last Updated On : 13/05/2021 09:09 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 6
# Total : 14
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 7
# Total : 7
# ----category_ end-------
#
# ----------END------------
# Name :  K P C Medical College and Hospital Govt Requisitioned (Govt. Requisitioned Pvt. Hospital)
# Address :   P/1-1, Jadavpur Station Rd, Jadavpur University Campus Area, Jadavpur, Kolkata, West Bengal 700032 , KOLKATA METROPOLITAN AREA
#   03340449700 Extn117 failed
# Phoneno : 0
# Total Beds : 200
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 12:09 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 181
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# Name :  Peerless Hospital Govt Requisitioned (Govt. Requisitioned Pvt. Hospital)
# Address :   360, Pancha Sayar Rd, Sahid Smirity Colony, Pancha Sayar, Kolkata, West Bengal 700094 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340111222
# Total Beds : 30
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 12:44 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# 1 items fetched.
# Name :  Rabindranath Tagore International Institute of Cardiac Sciences Category Private Hospital Govt. Requisitioned (Govt. Requisitioned Pvt. Hospital)
# Address :   Mukundapur Main Road, , Eastern Metropolitan Bypass, Mukundapur, Kolkata, West Bengal , KOLKATA METROPOLITAN AREA
# Phoneno : 8420000623
# Total Beds : 30
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 12:13 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Exiting from District : KOLKATA METROPOLITAN AREA Type : Govt. Requisitioned Pvt. Hospital Page No : 1
#
#
# 10
#
#
# 10 items fetched.
# Name :  All Asia Medical Institute A Unit Of Harsh Medical Centre Pvt Ltd (Private Hospital (Self Run))
# Address :   8B, Garcha, 1St Lane,Near Gariahat Pantaloons, Kolkata, West Bengal - 700019 ... , KOLKATA METROPOLITAN AREA
# Phoneno : 3340012200
# Total Beds : 50
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 02:59 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 32
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 13
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Name :  AMRI Hospital, Dhakuria (Private Hospital (Self Run))
# Address :   Block-A, Scheme-L11 P-4&5, Gariahat Rd, Dhakuria, Kolkata, West Bengal 700029 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366260000
# Total Beds : 164
# Available Beds : 10
# Verified On : Last Updated On : 12/05/2021 05:57 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 9
# Total : 95
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 26
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 11
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 1
# Total : 32
# ----category_ end-------
#
# ----------END------------
# Name :  AMRI Hospital, Mukundupur (Private Hospital (Self Run))
# Address :   230 Barakhola Lane, behind Metro Cash n Carry, Purba Jadavpur, Mukundapur, Kolkata, West Bengal 700099 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366061000
# Total Beds : 278
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:12 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 116
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 116
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 21
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 16
# ----category_ end-------
#
# ----------END------------
# Name :  AMRI, Salt Lake (Private Hospital (Self Run))
# Address :   16 17, JC Block Lane, Central Park Road Broadway Road, stadium gate number 3, opposite salt lake, Sector III, Bidhannagar, Kolkata, West Bengal 700098 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366063800
# Total Beds : 53
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 10:57 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 13
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 15
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 15
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 1
# Total : 10
# ----category_ end-------
#
# ----------END------------
# Name :  AMRI, Salt Lake - Hotel Monotel (Satellite Hotel)
# Address :   2, DM Block, Sector V, Bidhannagar, Kolkata, West Bengal 700091 , KOLKATA METROPOLITAN AREA
# Phoneno : 7044087872
# Total Beds : 22
# Available Beds : 4
# Verified On : Last Updated On : 13/05/2021 11:14 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 4
# Total : 22
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  AMRI, Salt Lake - Hotel Soujourn (Satellite Hotel)
# Address :   Plot No, KB 23, KB Block, Sector III, Bidhannagar, Kolkata, West Bengal 700098 , KOLKATA METROPOLITAN AREA
# Phoneno : 7044087872
# Total Beds : 24
# Available Beds : 10
# Verified On : Last Updated On : 13/05/2021 11:08 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 10
# Total : 24
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Anandalok Hospital (Private Hospital (Self Run))
# Address :   DK-7/3, 3rd Ave, beside National Dairy Development Board, Sector II, Bidhannagar, Kolkata, West Bengal 700091 , KOLKATA METROPOLITAN AREA
# Phoneno : 3323592932
# Total Beds : 62
# Available Beds : 62
# Verified On : Last Updated On : 13/05/2021 02:19 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 31
# Total : 31
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 31
# Total : 31
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Apex Clinic Private Limited (Private Hospital (Self Run))
# Address :   844/A, Raja Rammohan Roy Rd, Manton, Behala, Kolkata, West Bengal 700008 , KOLKATA METROPOLITAN AREA
# Phoneno : 3324068071
# Total Beds : 80
# Available Beds : 28
# Verified On : Last Updated On : 13/05/2021 10:14 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 14
# Total : 50
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 5
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 9
# Total : 22
# ----category_ end-------
#
# ----------END------------
# Name :  Apex Institute of Medical Sciences (Private Hospital (Self Run))
# Address :   1219, PG Survey Park Road, Sammilani Park Rd, near Big Bazar, Hiland Park, Survey Park, Santoshpur, Kolkata, West Bengal 700075 , KOLKATA METROPOLITAN AREA
# Phoneno : 3371256666
# Total Beds : 24
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 10:27 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 1
# Total : 6
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 14
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Apollo Gleneagles Hospital (Private Hospital (Self Run))
# Address :   58, Canal Circular Rd, Kadapara, Kankurgachi, Kolkata, West Bengal 700054 , KOLKATA METROPOLITAN AREA
#   9804000416 9804000246 8 PM to 8AM and Sundays and Holidays 9804000461 failed
# Phoneno : 0
# Total Beds : 337
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 04:04 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 256
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 32
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 26
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 23
# ----category_ end-------
#
# ----------END------------
# 10 items fetched.
# Name :  Apollo Gleneagles Hospital - VISITEL - A Boutique Hotel (Satellite Hotel)
# Address :   78, Canel Circular Road, Beside Apollo Hospital On EM, Bypass, Kolkata, West Bengal 700054 , KOLKATA METROPOLITAN AREA
#  9804000419 ( 8AM to 8PM)  failed
# Phoneno : 0
# Total Beds : 75
# Available Beds : 45
# Verified On : Last Updated On : 13/05/2021 03:59 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 45
# Total : 75
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Ashok Nursing Home (Private Hospital (Self Run))
# Address :   422, Raja Subodh Chandra Mallick Rd, Selimpur, Jodhpur Park, Kolkata, West Bengal 700068 , KOLKATA METROPOLITAN AREA
# Phoneno : 180030709555
# Total Beds : 5
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 12:46 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  B. P. PODDAR HOSPITAL MEDICAL RESEARCH LTD. (Private Hospital (Self Run))
# Address :   71/1, Humayun Kabir Sarani, Block G, New Alipore, Kolkata, West Bengal 700053 , KOLKATA METROPOLITAN AREA
# Phoneno : 9051588789
# Total Beds : 100
# Available Beds : 19
# Verified On : Last Updated On : 13/05/2021 12:52 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 19
# Total : 70
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# ----------END------------
# Name :  B. P. PODDAR HOSPITAL MEDICAL RESEARCH LTD. - B.P.Poddar and Parvati Devi Institute of Medical Sciences and Managements (Satellite Pvt. Building)
# Address :   45A, Manujendra Dutta Road, Gorabazar, Kolkata-700028 , KOLKATA METROPOLITAN AREA
# Phoneno : 9051588789
# Total Beds : 25
# Available Beds : 4
# Verified On : Last Updated On : 13/05/2021 12:57 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 4
# Total : 25
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Baine Hospital (Private Hospital (Self Run))
# Address :   123, 1, Gopal Lal Tagore Rd, Bonhooghly Government Colony, Baranagar, Kolkata, West , KOLKATA METROPOLITAN AREA
# Phoneno : 9674873262
# Total Beds : 70
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:57 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 45
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 21
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 4
# ----category_ end-------
#
# ----------END------------
# Name :  Belle Vue Clinic (Private Hospital (Self Run))
# Address :   9, Dr. U. N. Brahmachari Street (Formerly Loudon Street), Elgin, Kolkata, West Bengal 700017 , KOLKATA METROPOLITAN AREA
# Phoneno : 9331847265
# Total Beds : 236
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:17 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 190
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 32
# ----category_ end-------
#
# ----------END------------
# Name :  Belle Vue Clinic - Hotel Orion West Willows (Satellite Hotel)
# Address :   2, W Range, near Tata Motor lexus Showroom, Beck Bagan, Elgin, Kolkata, West Bengal 700017 , KOLKATA METROPOLITAN AREA
# Phoneno : 9330759579
# Total Beds : 50
# Available Beds : 24
# Verified On : Last Updated On : 13/05/2021 12:40 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 24
# Total : 50
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Bellona Nursing Home Diagnostic Centre Private Limited (Private Hospital (Self Run))
# Address :   51A, Diamond Harbour Rd, Mominpore, Kolkata, West Bengal 700027 , KOLKATA METROPOLITAN AREA
# Phoneno : 3324487059
# Total Beds : 10
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 02:36 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 2
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 3
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 2
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  Bhagirathi Neotia Woman and Child Care Centre (Private Hospital (Self Run))
# Address :   2, Rawdon St, Mullick Bazar, Park Street area, Kolkata, West Bengal 700017 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340405000
# Total Beds : 0
# Available Beds : 0
# Verified On : Last Updated On : 10/05/2021 12:53 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  BMRC HOSPITALS (Private Hospital (Self Run))
# Address :   6/6, Barrackpore Trunk Rd, Talpukur, Titagarh, Barrackpore, West Bengal 700120 , KOLKATA METROPOLITAN AREA
# Phoneno : 18003455500
# Total Beds : 33
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 11:52 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 7
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 1
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# ----------END------------
# 10 items fetched.
# Name :  Calcutta Heart Clinic, Salt Lake (Private Hospital (Self Run))
# Address :   3, 1st Cross Rd, HC Block, Sector III, Bidhannagar, Kolkata, West Bengal 700106 , KOLKATA METROPOLITAN AREA
# Phoneno : 9830999989
# Total Beds : 62
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:43 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 18
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 14
# ----category_ end-------
#
# ----------END------------
# Name :  Charnock Hospital (Private Hospital (Self Run))
# Address :   BMC 195, Biswa Bangla Sarani, Tegharia, Newtown, Kolkata, West Bengal 700157 , KOLKATA METROPOLITAN AREA
# Phoneno : 9831539000
# Total Beds : 212
# Available Beds : 2
# Verified On : Last Updated On : 13/05/2021 12:36 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 95
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 1
# Total : 111
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# ----------END------------
# Name :  Charnock Hospital - Hotel Eastern Plaza (Satellite Hotel)
# Address :   VIP Road, Military Camp Bus Stop, Kolkata, West Bengal 700157 , KOLKATA METROPOLITAN AREA
# Phoneno : 7044041000
# Total Beds : 40
# Available Beds : 38
# Verified On : Last Updated On : 13/05/2021 12:40 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 38
# Total : 40
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Charring Cross Nursing Home (Private Hospital (Self Run))
# Address :   2c, Motilal Basak Lane, Kadapara, Phool Bagan, Kankurgachi, Kolkata, West Bengal 700054 , KOLKATA METROPOLITAN AREA
# Phoneno : 3323598353
# Total Beds : 57
# Available Beds : 2
# Verified On : Last Updated On : 13/05/2021 12:01 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 13
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 35
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 1
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  Dafodil Nursing Home (Private Hospital (Self Run))
# Address :   No. 276, Canal St, Sreebhumi, Lake Town, Kolkata, West Bengal 700048 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340505555
# Total Beds : 92
# Available Beds : 7
# Verified On : Last Updated On : 13/05/2021 10:38 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 1
# Total : 11
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 37
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 1
# Total : 11
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 1
# Total : 7
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 2
# Total : 26
# ----category_ end-------
#
# ----------END------------
# Name :  DESUN Hospital - OYO SilverKey Hotel Mayfair Tower (Satellite Hotel)
# Address :   194, Hossenpur, EM Bypass (Chowbaga Road, Anandapur High Rd, Madurdaha, Hussainpur, Kolkata, West Bengal 700107 , KOLKATA METROPOLITAN AREA
# Phoneno : 9051715171
# Total Beds : 40
# Available Beds : 33
# Verified On : Last Updated On : 13/05/2021 09:42 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 33
# Total : 40
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Divine Nursing Home Pvt Ltd (Private Hospital (Self Run))
# Address :   11A, Avinash Chandra Banerjee Ln, Sura Cross Lane, Phool Bagan, Beleghata, Kolkata, West Bengal 700010 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340156789
# Total Beds : 65
# Available Beds : 4
# Verified On : Last Updated On : 13/05/2021 11:44 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 4
# Total : 62
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# Name :  DM Hospitals P Ltd. (Private Hospital (Self Run))
# Address :   113, James Long Sarani, Panchanan Tola, Thakurpukur, Kolkata, West Bengal 700063 , KOLKATA METROPOLITAN AREA
# Phoneno : 3324536221
# Total Beds : 14
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 03:13 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 7
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  Dreamland Nursing Home Kolkata (Private Hospital (Self Run))
# Address :   2, Naya Ratna Ln, Near Shyambazar Metro, Hati Bagan, Shyam Bazar, Kolkata, West Bengal 700004 , KOLKATA METROPOLITAN AREA
# Phoneno : 3325553217
# Total Beds : 13
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 01:06 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 11
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  Ekbalpur Nursing Home (Private Hospital (Self Run))
# Address :   9, Ibrahim Rd, Ekbalpur, Khidirpur, Kolkata, West Bengal 700023 , KOLKATA METROPOLITAN AREA
# Phoneno : 3371440909
# Total Beds : 60
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 03:20 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 26
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# 10 items fetched.
# Name :  Eskag Sanjeevani Multispeciality Hospital (Private Hospital (Self Run))
# Address :   P-48, Kshirode Vidyavinode Ave, Bag Bazar Colony, Baghbazar, Kolkata, West Bengal 700003 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340251800
# Total Beds : 36
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 01:37 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 14
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# ----------END------------
# Name :  Eves Clinic Nursing Home and PolyclinicMultispeciality nursing home (Private Hospital (Self Run))
# Address :   Junction Railway and Metro Station, 14F/1A, Near 11A bus terminus Dum Dum Road, DumDum, RBI Staff Quarters, Bir Para, Paikpara, Kolkata, West Bengal 700030 , KOLKATA METROPOLITAN AREA
# Phoneno : 8697112664
# Total Beds : 10
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 03:46 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 10
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Flemming Hospital Zodiac (Private Hospital (Self Run))
# Address :   1A, 1H, Topsia Rd, Mirania Gardens, East Topsia, Topsia, Kolkata, West Bengal 700046 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340686161
# Total Beds : 92
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 06:42 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 27
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 30
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 15
# ----category_ end-------
#
# ----------END------------
# Name :  Fortis Hospital Anandapur (Private Hospital (Self Run))
# Address :   730, Eastern Metropolitan Bypass, Anandapur, East Kolkata Twp, Kolkata, West Bengal 700107 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366284646
# Total Beds : 161
# Available Beds : 3
# Verified On : Last Updated On : 13/05/2021 11:57 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 3
# Total : 98
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 39
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 14
# ----category_ end-------
#
# ----------END------------
# Name :  Fortis Kidney Institute (Private Hospital (Self Run))
# Address :   111A, Rash Behari Ave, Dover Terrace, Gariahat, Kolkata, West Bengal 700029 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366276800
# Total Beds : 36
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:42 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 29
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# ----------END------------
# Name :  GD Hospital Diabetes Institute (Private Hospital (Self Run))
# ...
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 7
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# ----------END------------
# Name :  IRIS MULTISPECIALITY HOSPITAL (Private Hospital (Self Run))
# Address :   82, 1, Raja Subodh Chandra Mallick Rd, next to Big Bazaar, Vidyasagar Colony, Ganguly Bagan, Kolkata, West Bengal 700047 , KOLKATA METROPOLITAN AREA
# Phoneno : 8334922922
# Total Beds : 82
# Available Beds : 15
# Verified On : Last Updated On : 13/05/2021 10:46 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 13
# Total : 69
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 1
# Total : 3
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 1
# Total : 6
# ----category_ end-------
#
# ----------END------------
# Name :  JITENDRA NARAYAN RAY SISHU SEVA BHAWAN (Private Hospital (Self Run))
# Address :   58/1s raja dinendra street Kolkata-700006. , KOLKATA METROPOLITAN AREA
# Phoneno : 3329852985
# Total Beds : 40
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 05:09 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 25
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Name :  K P C Medical College and Hospital (Private Hospital (Self Run))
# Address :   P/1-1, Jadavpur Station Rd, Jadavpur University Campus Area, Jadavpur, Kolkata, West Bengal 700032 , KOLKATA METROPOLITAN AREA
#   03340449700 Extn117 failed
# Phoneno : 0
# Total Beds : 26
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 12:11 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 18
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# Name :  Kasturi Medical Centre Pvt Ltd. (Private Hospital (Self Run))
# Address :   5, Diamond Harbour Road Opp 3A Bus Terminus, Diamond Park, Joka, Kolkata, West Bengal 700104 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366141915
# Total Beds : 74
# Available Beds : 5
# Verified On : Last Updated On : 13/05/2021 10:49 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 5
# Total : 61
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# Name :  Kolkata Port Trust Hospital, Centenary Hospital (Private Hospital (Self Run))
# Address :   block a, 1, Diamond Harbour Rd, Uttar Raypur, New Alipore, Kolkata, West Bengal 700053 , KOLKATA METROPOLITAN AREA
# Phoneno : 3324014503
# Total Beds : 80
# Available Beds : 7
# Verified On : Last Updated On : 13/05/2021 12:13 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 36
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 6
# Total : 40
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 1
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Kothari Medical Centre (Private Hospital (Self Run))
# Address :   8/3, Alipore Rd, Alipore, Kolkata, West Bengal 700027 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340127000
# Total Beds : 168
# Available Beds : 14
# Verified On : Last Updated On : 13/05/2021 11:16 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 10
# Total : 12
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 4
# Total : 134
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 12
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# ----------END------------
# Name :  Marwari Relief Society Hospital (Private Hospital (Self Run))
# Address :   225, 227, Rabindra Sarani, Raja Katra, Jorasanko, Kolkata, West Bengal 700007 , KOLKATA METROPOLITAN AREA
# Phoneno : 22743722
# Total Beds : 60
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 05:56 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 17
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 24
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Medica Covid Hospital - Kishore Bharati Stadium. (Private Hospital (Self Run))
# Address :   B-278, Survey Park Rd, Purba Diganta, Santoshpur, Kolkata, West Bengal 700075 , KOLKATA METROPOLITAN AREA
# Phoneno : 7044488841
# Total Beds : 60
# Available Beds : 10
# Verified On : Last Updated On : 13/05/2021 10:48 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 10
# Total : 28
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 32
# ----category_ end-------
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Medica Superspecialty Hospital (Private Hospital (Self Run))
# Address :   127, Eastern Metropolitan Bypass, Nitai Nagar, Mukundapur, Kolkata, West Bengal 700099 , KOLKATA METROPOLITAN AREA
# Phoneno : 7044488841
# Total Beds : 264
# Available Beds : 11
# Verified On : Last Updated On : 13/05/2021 11:14 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 11
# Total : 122
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 45
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 57
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 40
# ----category_ end-------
#
# ----------END------------
# 10 items fetched.
# Name :  Medica Superspecialty Hospital - Laxmi Guest House (Satellite Hotel)
# Address :   298 mukundpur main road, Mukundapur, Kolkata - 700099, Opposite Avidipta Gate 1, Near Purba Jadavpur Police Station , KOLKATA METROPOLITAN AREA
# Phoneno : 3366520000
# Total Beds : 24
# Available Beds : 14
# Verified On : Last Updated On : 13/05/2021 10:16 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 14
# Total : 24
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Medica Superspecialty Hospital - Medica Annex II (Satellite Hotel)
# Address :   Apposite to Acropolis Mall, Kolkata 107 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366520000
# Total Beds : 38
# Available Beds : 28
# Verified On : Last Updated On : 13/05/2021 10:18 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 28
# Total : 38
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  MEDIVIEW (Private Hospital (Self Run))
# Address :   74, Broad St, Ballygunge Park, Ballygunge, Kolkata, West Bengal 700019 , KOLKATA METROPOLITAN AREA
# Phoneno : 3340208989
# Total Beds : 42
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 12:37 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 28
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# ----------END------------
# Name :  Mission of Mercy Hospital Research Centre (Private Hospital (Self Run))
# Address :   No. 125, 1, Park St, Dharmatala, Taltala, Kolkata, West Bengal 700016 , KOLKATA METROPOLITAN AREA
# Phoneno : 9836008484
# Total Beds : 70
# Available Beds : 19
# Verified On : Last Updated On : 13/05/2021 11:04 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 2
# Total : 10
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 13
# Total : 44
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 4
# Total : 9
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# Name :  Mission of Mercy Hospital Research Centre - SIAMTON INN (Satellite Hotel)
# Address :   56, Park Street. Kolkata , KOLKATA METROPOLITAN AREA
# Phoneno : 9836008484
# Total Beds : 15
# Available Beds : 14
# Verified On : Last Updated On : 13/05/2021 10:57 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 14
# Total : 15
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  NABAJIBAN HOSPITAL PVT.LTD. (Private Hospital (Self Run))
# Address :   5, SHIBDAS BHADURI STREET,KOLKATA-700004 , KOLKATA METROPOLITAN AREA
# Phoneno : 3325551544
# Total Beds : 42
# Available Beds : 5
# Verified On : Last Updated On : 13/05/2021 12:52 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 4
# Total : 28
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 1
# Total : 9
# ----category_ end-------
#
# ----------END------------
# Name :  Narayan Memorial Hospital, Behala (Private Hospital (Self Run))
# Address :   Narayan Memorial Hospital, 601, Diamond Harbour Rd, Shimultala, Manton, Behala, Kolkata, West Bengal 700034 , KOLKATA METROPOLITAN AREA
# Phoneno : 9674446902
# Total Beds : 23
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 10:19 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 12
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# Name :  Nehru Memorial Techno Global Hospital (Private Hospital (Self Run))
# Address :   6, Barasat road, Lalkuthi, Barrackpore, West Bengal 700120 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366303030
# Total Beds : 70
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 08:23 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 53
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 7
# ----category_ end-------
#
# ----------END------------
# Name :  Nightingale Hospital (Private Hospital (Self Run))
# Address :   11 Shakespeare Sarani Kolkata-71 , KOLKATA METROPOLITAN AREA
# Phoneno : 3335005949
# Total Beds : 48
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 01:03 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 38
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 4
# ----category_ end-------
#
# ----------END------------
# Name :  North City Hospital (Private Hospital (Self Run))
# Address :   73 & 81B, Bagmari Road, Near Ultadanga Hudco Stop, Kolkata, West Bengal 700054 , KOLKATA METROPOLITAN AREA
# Phoneno : 3366050999
# Total Beds : 74
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 12:09 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 56
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 4
# ----category_ end-------
#
# ----------END------------

# %%
# select_district_and_wait_until_load(driver,wait,"BANKURA")
# select_hospital_type(driver,3)
# no_of_pages = no_of_pages_for_selected_district_and_type(driver)
# print(no_of_pages)
# global_buggy_pnum = 0
# for pg_no in range(no_of_pages):
#     print(f"\nGoing on page {pg_no+1}\n")
#     if pg_no != 0 :
#         global_buggy_pnum = pg_no
#         select_page_pagination_section(driver,pg_no+1)
#         toggle_detailed_break_up_section(driver)

#     toggle_detailed_break_up_section(driver)
#     scrape_data(driver)
# print(f"Exiting from District : {district_lable} Type : {hospital_type} Page No : {pg_no}")

# %%
# select_district_and_wait_until_load(driver,wait,"BANKURA")
# select_hospital_type(driver,2)
# # select_page_pagination_section(driver,3)
# scrape_data(driver)

# %%
# !git add .
# !git commit -m "update"
# !git push origin main
