# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC 
from selenium.webdriver.support.ui import WebDriverWait
import os,time,re,math
from selenium.common.exceptions import StaleElementReferenceException

# %%
# Pre-processed datas to match with current backend system
using_district_list = {
    "ALIPURDUAR": 719,
    "BANKURA": 720,
    "BIRBHUM": 721,
    "COOCHBEHAR": 722,
    "DAKSHIN 24 PARGANA": 740,
    "DAKSHIN DINAJPUR": 723,
    "DARJEELING": 724,
    "HOOGHLY": 725,
    "HOWRAH": 726,
    "JALPAIGURI": 727,
    "JHARGRAM": 728,
    "KALIMPONG": 729,
    "KOLKATA METROPOLITAN AREA": 730,
    "MALDA": 731,
    "MURSHIDABAD": 732,
    "NADIA": 733,
    "PASCHIM BARDHAMAN": 735,
    "PASCHIM MEDINIPUR": 736,
    "PURBA BARDHHAMAN": 737,
    "PURBA MEDINIPUR": 738,
    "PURULIA": 739,
    "UTTAR 24 PARGANA": 734,
    "UTTAR DINAJPUR": 741
}

using_hospital_type={
    "Government Hospital": {
        "dbkey": "govt",
        "webkey": 1
    },
    "Govt. Requisitioned Pvt. Hospital": {
        "dbkey": "pvtundergovt",
        "webkey": 2
    },
    "Private Hospital": {
        "dbkey": "private",
        "webkey": 3
    }
}

# Config
PATH_TO_DRIVER = r'/usr/bin/chromedriver'
endpoint = 'https://excise.wb.gov.in/CHMS/Public/Page/CHMS_Public_Hospital_Bed_Availability.aspx'


chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--window-size=1920x1080")


#Functions

#Init
def init_scrape(chrome_options,endpoint,PATH_TO_DRIVER=r'/usr/bin/chromedriver'):
    driver = webdriver.Chrome(executable_path = PATH_TO_DRIVER, options=chrome_options)
    driver.get(endpoint)
    wait = WebDriverWait(driver,20)
    wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_ddl_District")))
    return driver,wait

# Select Radio Buttons
def select_hospital_type(driver,label):
    try:
        radio = driver.find_element_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_rdo_Govt_Flag']/label[{}]".format(str(label)))
        radio.click()
    except:
        raise Exception("ERROR : Can't Select Hospital Type")
        
        
# Click on <DISTRICT_NAME> district and load the pages
def select_district_and_wait_until_load(driver,wait,district_name):
    try:
        driver.find_element_by_xpath("//select[@name='ctl00$ContentPlaceHolder1$ddl_District']/option[text()='{}']".format(district_name)).click()
        driver.implicitly_wait(10)
        wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_GridView2")))
    except:
        raise Exception("ERROR : Can't select district")
        

# Get no of pages (Pagination) for selected district
def no_of_pages_for_selected_district_and_type(driver):
    try:
        pages=len(driver.find_elements_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_GridView2']/tbody/tr[1]/td/table/tbody/tr/td"))
        if pages==0:
            pages =1
        return pages
    except:
        raise Exception("ERROR : Can't get number of pages for selected district and type")
        
# Select page
def select_page_pagination_section(driver,page_no):
    try:
        driver.find_element_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_GridView2']/tbody/tr[1]/td/table/tbody/tr/td[{}]/a".format(str(page_no))).click()
        driver.implicitly_wait(10)

    except:
        raise Exception("ERROR : Switching page for pagination")
        
        
# Click on all the "View Detailed break up option"
def toggle_detailed_break_up_section(driver):
    try:
        driver.find_element_by_xpath("//*[contains(@id,'_div_card')]/div[2]/div[2]/div[1]/a").click()
    except:
        raise Exception("ERROR : Can't open detailed break up section")

        
def MobileCleanData(data):
    # Process data for DB
    # Database only have Big Integer field , String not accepted
    result = []
    copydata = None
    # Split data at "/" & "," for multiple mobile number
    if "/" in str(data):
        copydata = str(data).split("/")
    elif "," in str(data):
        copydata = str(data).split(",")
    else:
        copydata = [data]

    for item in copydata:
        try:
            # Remove "+"
            # Remove "(" & ")"
            # Remove "-"
            # Remove all blank spaces
            tmp = item.replace("+","").replace("(","").replace(")","").replace("-","").replace(" ","") 
            
            # Check whether its is empty or not before typecasting to int to reduce possibility of error
            if tmp.strip() != "":
                result.append(int(tmp))
        
        except ValueError:
            print(f"{item} failed")
    # Will return a tupple of (<No of mobile numbers>, [list of <mobileno>])
    return len(result),result


# Main Driver function for scraping
def scrape_data(driver):
    # Get the list of hospotals entry
    entries = driver.find_elements_by_xpath("//*[contains(@id,'_div_card')]")
    
    if len(entries) == 0 :
        print("No items found")
        return
    

    # No of hospitals under selected category and dsitrct
    print(str(len(entries)) + " items fetched.")

    # Iterate through the entried and print the details
    for ei,e in enumerate(entries):
    #     print(ei)
        print("Name : {}".format(e.find_element_by_xpath(".//h5").text))
        print("Address : {}".format(e.find_element_by_xpath("(.//div/div/div)[1]").text))
        print("Phoneno : {}".format(MobileCleanData(e.find_element_by_xpath("(.//div/div/div)[2]//a").text)[1][0]))
        print("Total Beds : {}".format(e.find_element_by_xpath(".//div[2]/div[1]/div[4]/div/ul/li[1]/h3").text))
        print("Available Beds : {}".format(e.find_element_by_xpath(".//div[2]/div[1]/div[4]/div/ul/li[2]/h3").text))
        print("Verified On : {}".format(e.find_element_by_xpath(".//div[3]/small").text))
        print("------------------------")
        bed_categories = e.find_elements_by_xpath(".//div[2]/div[2]/div[2]/div/div")
        print("Categories of beds : {}".format(len(bed_categories)))
        for bc in bed_categories:
            # Make sure you have click on "View detailed Details" else you will get blank details
            try:
                print("Category : {}".format(bc.find_element_by_xpath(".//div/div[1]").text))
                print("Available : {}".format(bc.find_element_by_xpath(".//div/div[2]/div/div[4]/div/ul/li[2]/h3").text))
                print("Total : {}".format(bc.find_element_by_xpath(".//div/div[2]/div/div[4]/div/ul/li[1]/h3").text))
            except:
                print("Due to error skipping the category section")
            print("----category_ end-------\n")
            
        print("----------END------------")

# %%
# List of districts
# district_list = driver.find_element_by_id("ctl00_ContentPlaceHolder1_ddl_District")
# final_district_list = []
# for i in district_list.text.split("\n")[1:-1]:
#     final_district_list.append(i.strip())

# %%
# Options Radio Buttons
# RADIO_BUTTONS = driver.find_elements_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_rdo_Govt_Flag']/label")
# for i,j in enumerate(RADIO_BUTTONS):
#     print(j.text,i)

# %% [markdown]
# ## Test Code

# %% [markdown]
# ### Steps one-by-one
# * Call initialize Function > init_scrape
# * First select the hospital type > select_hospital_type
# * Then select district > select_district_and_wait_until_load
# * Get page no > no_of_pages_for_selected_district_and_type
# * Iterate through Pages
#     * Call this function > toggle_detailed_break_up_section
#     * Call scrape data to start scraping > scrape_data

# %%
driver,wait = init_scrape(chrome_options,endpoint)

# %%
for district_lable,district_id in using_district_list.items():
#     print(district_lable,district_id)
    select_district_and_wait_until_load(driver,wait,district_lable)
    for hospital_type in using_hospital_type:
        select_hospital_type(driver,using_hospital_type[hospital_type]["webkey"])
        no_of_pages = no_of_pages_for_selected_district_and_type(driver)
        
        global_buggy_pnum = 0
        for pg_no in range(no_of_pages):
            if pg_no != 0 or (pg_no==0 and global_buggy_pnum!=0) :
                global_buggy_pnum = pg_no
                select_page_pagination_section(driver,pg_no+1)
                
            toggle_detailed_break_up_section(driver)
            scrape_data(driver)
        print(f"Exiting from District : {district_lable} Type : {hospital_type} Page No : {pg_no}")
# Out:
# 3 items fetched.
# Name :  DISTRICT HOSPITAL (Government Hospital)
# Address :   ALIPURDUAR , ALIPURDUAR
# Phoneno : 9677028903
# Total Beds : 15
# Available Beds : 9
# Verified On : Last Updated On : 13/05/2021 12:03 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 9
# Total : 15
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  FALAKATA SUPER SPECIALITY HOSPITAL (Government Hospital)
# Address :   FALAKATA, ALIPURDUAR , ALIPURDUAR
# Phoneno : 8420507892
# Total Beds : 50
# Available Beds : 50
# Verified On : Last Updated On : 13/05/2021 11:50 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 40
# Total : 40
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 10
# Total : 10
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  TOPSIKHATA COVID HOSPITAL (Government Hospital)
# Address :   TOPSIKHATA,ALIPURDUAR-1 , ALIPURDUAR
# Phoneno : 9836055469
# Total Beds : 110
# Available Beds : 61
# Verified On : Last Updated On : 13/05/2021 11:19 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 45
# Total : 69
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 10
# Total : 24
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 5
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 1
# Total : 7
# ----category_ end-------
#
# ----------END------------
# Exiting from District : ALIPURDUAR Type : Government Hospital Page No : 0
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-2-a0755a190131> in toggle_detailed_break_up_section(driver)
#     104     try:
# --> 105         driver.find_element_by_xpath("//*[contains(@id,'_div_card')]/div[2]/div[2]/div[1]/a").click()
#     106     except:
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'_div_card')]/div[2]/div[2]/div[1]/a"}
#   (Session info: headless chrome=90.0.4430.93)
#
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-860f5a543a59> in <module>
#      12                 select_page_pagination_section(driver,pg_no+1)
#      13
# ---> 14             toggle_detailed_break_up_section(driver)
#      15             scrape_data(driver)
#      16         print(f"Exiting from District : {district_lable} Type : {hospital_type} Page No : {pg_no}")
#
# <ipython-input-2-a0755a190131> in toggle_detailed_break_up_section(driver)
#     105         driver.find_element_by_xpath("//*[contains(@id,'_div_card')]/div[2]/div[2]/div[1]/a").click()
#     106     except:
# --> 107         raise Exception("ERROR : Can't open detailed break up section")
#     108
#     109
#
# Exception: ERROR : Can't open detailed break up section

# %%
select_district_and_wait_until_load(driver,wait,"BANKURA")
select_hospital_type(driver,3)
no_of_pages = no_of_pages_for_selected_district_and_type(driver)
print(no_of_pages)
global_buggy_pnum = 0
for pg_no in range(no_of_pages):
    print(f"\nGoing on page {pg_no+1}\n")
    if pg_no != 0 :
        global_buggy_pnum = pg_no
        select_page_pagination_section(driver,pg_no+1)
        toggle_detailed_break_up_section(driver)

    toggle_detailed_break_up_section(driver)
    scrape_data(driver)
print(f"Exiting from District : {district_lable} Type : {hospital_type} Page No : {pg_no}")
# Out:
# 3
#
# Going on page 1
#
# 10 items fetched.
# Name :  ADSR New Building (Safe Home)
# Address :   Haripur, Indas, bankura , BANKURA
# Phoneno : 9434754996
# Total Beds : 40
# Available Beds : 30
# Verified On : Last Updated On : 12/05/2021 04:21 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 30
# Total : 40
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Ailakundi PTTI (Safe Home)
# Address :   Behind Bankura SBSTC Bus Stand , BANKURA
# Phoneno : 9434440300
# Total Beds : 30
# Available Beds : 18
# Verified On : Last Updated On : 12/05/2021 08:20 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 18
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  ANAMOY POLYCLINIC DIAGNOSTIC CENTRE HOSPITAL (Private Hospital (Self Run))
# Address :   KENDUADIHI, BANKURA , BANKURA
# Phoneno : 9732319959
# Total Beds : 10
# Available Beds : 6
# Verified On : Last Updated On : 12/05/2021 05:42 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 5
# Total : 8
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 1
# Total : 2
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Bagdiha BJRCY Hostel (Safe Home)
# Address :   Bagdiha, Indpur , BANKURA
# Phoneno : 7063017340
# Total Beds : 27
# Available Beds : 26
# Verified On : Last Updated On : 12/05/2021 09:54 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 26
# Total : 27
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Banabitan Lodge (Safe Home)
# Address :   Joypur, Bankura , BANKURA
# Phoneno : 9641599486
# Total Beds : 23
# Available Beds : 5
# Verified On : Last Updated On : 12/05/2021 02:31 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 5
# Total : 23
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  BANKURA NURSING HOME (Private Hospital (Self Run))
# Address :   PATPUR BANKURA , BANKURA
# Phoneno : 9564280791
# Total Beds : 16
# Available Beds : 1
# Verified On : Last Updated On : 12/05/2021 07:38 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 1
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  BANKURA SEVA NIKETAN HOSPITAL (Private Hospital (Self Run))
# Address :   PATPUR, JAIL ROAD, BANKURA , BANKURA
# Phoneno : 7797701790
# Total Beds : 36
# Available Beds : 2
# Verified On : Last Updated On : 12/05/2021 07:06 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 36
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  CCRD (Safe Home)
# Address :   Panchmura , BANKURA
# Phoneno : 7001215610
# Total Beds : 20
# Available Beds : 15
# Verified On : Last Updated On : 12/05/2021 08:34 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 15
# Total : 20
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  CURE HOSPITAL (Private Hospital (Self Run))
# Address :   LOKEPUE, KENDUADIHI, BANKURA 722102 , BANKURA
# Phoneno : 9732512000
# Total Beds : 16
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 06:10 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Dhansimla Bidyabhaban Hostel (Safe Home)
# Address :   Dhansimla, Sonamukhi , BANKURA
# Phoneno : 9749815197
# Total Beds : 20
# Available Beds : 20
# Verified On : Last Updated On : 12/05/2021 04:54 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 16
# Total : 16
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 4
# Total : 4
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
#
# Going on page 2
#
# 10 items fetched.
# Name :  ADSR New Building (Safe Home)
# Address :   Haripur, Indas, bankura , BANKURA
# Phoneno : 9434754996
# Total Beds : 40
# Available Beds : 30
# Verified On : Last Updated On : 12/05/2021 04:21 PM
# ------------------------
# Categories of beds : 5
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# ----------END------------
# Name :  Ailakundi PTTI (Safe Home)
# Address :   Behind Bankura SBSTC Bus Stand , BANKURA
# Phoneno : 9434440300
# Total Beds : 30
# Available Beds : 18
# Verified On : Last Updated On : 12/05/2021 08:20 AM
# ------------------------
# Categories of beds : 5
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# ----------END------------
# Name :  ANAMOY POLYCLINIC DIAGNOSTIC CENTRE HOSPITAL (Private Hospital (Self Run))
# Address :   KENDUADIHI, BANKURA , BANKURA
# Phoneno : 9732319959
# Total Beds : 10
# Available Beds : 6
# Verified On : Last Updated On : 12/05/2021 05:42 PM
# ------------------------
# Categories of beds : 5
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# ----------END------------
# Name :  Bagdiha BJRCY Hostel (Safe Home)
# Address :   Bagdiha, Indpur , BANKURA
# Phoneno : 7063017340
# Total Beds : 27
# Available Beds : 26
# Verified On : Last Updated On : 12/05/2021 09:54 PM
# ------------------------
# Categories of beds : 5
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# ----------END------------
# Name :  Banabitan Lodge (Safe Home)
# Address :   Joypur, Bankura , BANKURA
# Phoneno : 9641599486
# Total Beds : 23
# Available Beds : 5
# Verified On : Last Updated On : 12/05/2021 02:31 PM
# ------------------------
# Categories of beds : 5
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# ----------END------------
# Name :  BANKURA NURSING HOME (Private Hospital (Self Run))
# Address :   PATPUR BANKURA , BANKURA
# Phoneno : 9564280791
# Total Beds : 16
# Available Beds : 1
# Verified On : Last Updated On : 12/05/2021 07:38 PM
# ------------------------
# Categories of beds : 5
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# ----------END------------
# Name :  BANKURA SEVA NIKETAN HOSPITAL (Private Hospital (Self Run))
# Address :   PATPUR, JAIL ROAD, BANKURA , BANKURA
# Phoneno : 7797701790
# Total Beds : 36
# Available Beds : 2
# Verified On : Last Updated On : 12/05/2021 07:06 PM
# ------------------------
# Categories of beds : 5
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# ----------END------------
# Name :  CCRD (Safe Home)
# Address :   Panchmura , BANKURA
# Phoneno : 7001215610
# Total Beds : 20
# Available Beds : 15
# Verified On : Last Updated On : 12/05/2021 08:34 PM
# ------------------------
# Categories of beds : 5
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Category :
# Available :
# Total :
# ----category_ end-------
#
# Due to error skipping the category section
# ----category_ end-------
#
# Due to error skipping the category section
# ----category_ end-------
#
# ----------END------------
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-44-5c8b0f512b65> in <module>
#      12
#      13     toggle_detailed_break_up_section(driver)
# ---> 14     scrape_data(driver)
#      15 print(f"Exiting from District : {district_lable} Type : {hospital_type} Page No : {pg_no}")
#
# <ipython-input-40-a0755a190131> in scrape_data(driver)
#     155     for ei,e in enumerate(entries):
#     156     #     print(ei)
# --> 157         print("Name : {}".format(e.find_element_by_xpath(".//h5").text))
#     158         print("Address : {}".format(e.find_element_by_xpath("(.//div/div/div)[1]").text))
#     159         print("Phoneno : {}".format(MobileCleanData(e.find_element_by_xpath("(.//div/div/div)[2]//a").text)[1][0]))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_xpath(self, xpath)
#     349             element = element.find_element_by_xpath('//div/td[1]')
#     350         """
# --> 351         return self.find_element(by=By.XPATH, value=xpath)
#     352
#     353     def find_elements_by_xpath(self, xpath):
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     656                 value = '[name="%s"]' % value
#     657
# --> 658         return self._execute(Command.FIND_CHILD_ELEMENT,
#     659                              {"using": by, "value": value})['value']
#     660
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: headless chrome=90.0.4430.93)

# %%
select_district_and_wait_until_load(driver,wait,"PURBA BARDHHAMAN")
select_hospital_type(driver,3)
select_page_pagination_section(driver,3)
toggle_detailed_break_up_section(driver)
scrape_data(driver)
# Out:
# 10 items fetched.
# Name :  Adarsh Nursing Home (Private Hospital (Self Run))
# Address :   84, BC Road, Sulipukur, Rajbati, Burdwan - 713104 , PURBA BARDHHAMAN
# Phoneno : 9434358232
# Total Beds : 16
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 05:34 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Annapurna Nursing Home (Private Hospital (Self Run))
# Address :   Garh More, NH2 Bypass Road. Uttara Bus Stand, Fagupur, Burdwan- 713101 , PURBA BARDHHAMAN
# Phoneno : 7908978011
# Total Beds : 15
# Available Beds : 2
# Verified On : Last Updated On : 12/05/2021 07:17 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 13
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# ----------END------------
# Name :  Asha Nursing Home Diagnostic Centre and Polyclinic (Private Hospital (Self Run))
# Address :   Nawabhat, G.T. Road (Near Bank of India), Purba Bardhaman (W.B) , PURBA BARDHHAMAN
# Phoneno : 9732075276
# Total Beds : 30
# Available Beds : 1
# Verified On : Last Updated On : 12/05/2021 06:36 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 14
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 1
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# ----------END------------
# Name :  Astha Nursing Home (Private Hospital (Self Run))
# Address :   189/851, Memari New Bus Stand, Memari - 713146 , PURBA BARDHHAMAN
# Phoneno : 9434666539
# Total Beds : 0
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 07:38 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Bengal Faith Hospital (Private Hospital (Self Run))
# Address :   GT Road, Goda , PURBA BARDHHAMAN
# Phoneno : 7596073422
# Total Beds : 17
# Available Beds : 4
# Verified On : Last Updated On : 12/05/2021 06:27 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 3
# Total : 12
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 1
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Name :  BIMS Hospital (Private Hospital (Self Run))
# Address :   294, GT Road, Bhangakuthi, Rajbati, Burdwan- 713104 , PURBA BARDHHAMAN
# Phoneno : 9232146170
# Total Beds : 25
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 05:49 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# Name :  Burdwan Critical Care Unit Pvt. Ltd. (Private Hospital (Self Run))
# Address :   32,7 RB Ghosh Road, Burdwan - 713101 , PURBA BARDHHAMAN
# Phoneno : 9434177774
# Total Beds : 25
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 05:18 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 24
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  CHITTARANJAN ADVANCED MEDICAL REFERRAL INSTITUTE- A UNIT OF BURDWAN DIAGNOSTIC RESEARCH CENTRE PVT. LTD. (Private Hospital (Self Run))
# Address :   838, Bamchandaipur, P.O.- Joteram, P.S.- Burdwan, Joteram - 713104 , PURBA BARDHHAMAN
# Phoneno : 9233361670
# Total Beds : 63
# Available Beds : 13
# Verified On : Last Updated On : 12/05/2021 07:23 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 6
# Total : 35
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 2
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 2
# Total : 20
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 3
# Total : 4
# ----category_ end-------
#
# ----------END------------
# Name :  Dishan Nursing Home (Private Hospital (Self Run))
# Address :   Nababhat More, GT Road , PURBA BARDHHAMAN
# Phoneno : 9851669877
# Total Beds : 7
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 06:55 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 1
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 1
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  Dreamland Nursing Home (Private Hospital (Self Run))
# Address :   962/1, Indraprastha, Rajbati, Burdwan- 713104 , PURBA BARDHHAMAN
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-50-4809584ea21a> in <module>
#       3 select_page_pagination_section(driver,3)
#       4 toggle_detailed_break_up_section(driver)
# ----> 5 scrape_data(driver)
#
# <ipython-input-40-a0755a190131> in scrape_data(driver)
#     157         print("Name : {}".format(e.find_element_by_xpath(".//h5").text))
#     158         print("Address : {}".format(e.find_element_by_xpath("(.//div/div/div)[1]").text))
# --> 159         print("Phoneno : {}".format(MobileCleanData(e.find_element_by_xpath("(.//div/div/div)[2]//a").text)[1][0]))
#     160         print("Total Beds : {}".format(e.find_element_by_xpath(".//div[2]/div[1]/div[4]/div/ul/li[1]/h3").text))
#     161         print("Available Beds : {}".format(e.find_element_by_xpath(".//div[2]/div[1]/div[4]/div/ul/li[2]/h3").text))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: headless chrome=90.0.4430.93)
