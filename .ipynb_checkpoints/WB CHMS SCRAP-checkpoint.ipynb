# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC 
from selenium.webdriver.support.ui import WebDriverWait
import os,time,re,math
from selenium.common.exceptions import StaleElementReferenceException

# %%
# Pre-processed datas to match with current backend system
using_district_list = {
    "ALIPURDUAR": 719,
    "BANKURA": 720,
    "BIRBHUM": 721,
    "COOCHBEHAR": 722,
    "DAKSHIN 24 PARGANA": 740,
    "DAKSHIN DINAJPUR": 723,
    "DARJEELING": 724,
    "HOOGHLY": 725,
    "HOWRAH": 726,
    "JALPAIGURI": 727,
    "JHARGRAM": 728,
    "KALIMPONG": 729,
    "KOLKATA METROPOLITAN AREA": 730,
    "MALDA": 731,
    "MURSHIDABAD": 732,
    "NADIA": 733,
    "PASCHIM BARDHAMAN": 735,
    "PASCHIM MEDINIPUR": 736,
    "PURBA BARDHHAMAN": 737,
    "PURBA MEDINIPUR": 738,
    "PURULIA": 739,
    "UTTAR 24 PARGANA": 734,
    "UTTAR DINAJPUR": 741
}

using_hospital_type={
    "Government Hospital": {
        "dbkey": "govt",
        "webkey": 1
    },
    "Govt. Requisitioned Pvt. Hospital": {
        "dbkey": "pvtundergovt",
        "webkey": 2
    },
    "Private Hospital": {
        "dbkey": "private",
        "webkey": 3
    }
}

# Config
PATH_TO_DRIVER = r'/usr/bin/chromedriver'
endpoint = 'https://excise.wb.gov.in/CHMS/Public/Page/CHMS_Public_Hospital_Bed_Availability.aspx'


chrome_options = Options()
# chrome_options.add_argument("--headless")
# chrome_options.add_argument("--window-size=1920x1080")


#Functions

#Init
def init_scrape(chrome_options,endpoint,PATH_TO_DRIVER=r'/usr/bin/chromedriver'):
    driver = webdriver.Chrome(executable_path = PATH_TO_DRIVER, options=chrome_options)
    driver.get(endpoint)
    wait = WebDriverWait(driver,30)
    wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_ddl_District")))
    return driver,wait

# Track the loading spinner
def still_loading(driver,wait):
    try:
        return driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_upPgo"]').value_of_css_property("display")
    except:
        return "done"
    
    
# Select Radio Buttons
def select_hospital_type(driver,label):
    try:
        radio = driver.find_element_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_rdo_Govt_Flag']/label[{}]".format(str(label)))
        radio.click()
        driver.implicitly_wait(10)
    except:
        raise Exception("ERROR : Can't Select Hospital Type")
        
        
# Click on <DISTRICT_NAME> district and load the pages
def select_district_and_wait_until_load(driver,wait,district_name):
    try:
        driver.find_element_by_xpath("//select[@name='ctl00$ContentPlaceHolder1$ddl_District']/option[text()='{}']".format(district_name)).click()
        while still_loading(driver,wait) != "none":
            driver.implicitly_wait(2)
        driver.implicitly_wait(5)
        wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_GridView2")))
    except:
        raise Exception("ERROR : Can't select district")
        

# Get no of pages (Pagination) for selected district
def no_of_pages_for_selected_district_and_type(driver):
    try:
        pages=len(driver.find_elements_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_GridView2']/tbody/tr[1]/td/table/tbody/tr/td"))
        if pages == 0:
            pages = 1
        return pages
    except:
        raise Exception("ERROR : Can't get number of pages for selected district and type")
        
# Select page
def select_page_pagination_section(driver,page_no):
    try:
        driver.find_element_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_GridView2']/tbody/tr[1]/td/table/tbody/tr/td[{}]/a".format(str(page_no))).click()
        while still_loading(driver,wait) != "none":
            driver.implicitly_wait(2)
        driver.implicitly_wait(2)
        wait.until(EC.element_to_be_clickable((By.ID,"ctl00_ContentPlaceHolder1_GridView2")))
    except:
        raise Exception("ERROR : Switching page for pagination")
        
        
# Click on all the "View Detailed break up option"
def toggle_detailed_break_up_section(driver):
    try:
        driver.find_element_by_xpath("//*[contains(@id,'_div_card')]/div[2]/div[2]/div[1]/a").click()
        driver.implicitly_wait(5)
    except:
        raise Exception("ERROR : Can't open detailed break up section")

        
def MobileCleanData(data):
    # Process data for DB
    # Database only have Big Integer field , String not accepted
    result = []
    copydata = None
    # Split data at "/" & "," for multiple mobile number
    if "/" in str(data):
        copydata = str(data).split("/")
    elif "," in str(data):
        copydata = str(data).split(",")
    else:
        copydata = [data]

    for item in copydata:
        try:
            # Remove "+"
            # Remove "(" & ")"
            # Remove "-"
            # Remove all blank spaces
            tmp = item.replace("+","").replace("(","").replace(")","").replace("-","").replace(" ","") 
            
            # Check whether its is empty or not before typecasting to int to reduce possibility of error
            if tmp.strip() != "":
                result.append(int(tmp))
        
        except ValueError:
            print(f"{item} failed")
    # Will return a tupple of (<No of mobile numbers>, [list of <mobileno>])
    return len(result),result


scraping  = False

# Main Driver function for scraping
def scrape_data(driver):
    scraping = True

    # Get the list of hospotals entry
    entries = driver.find_elements_by_xpath("//*[contains(@id,'_div_card')]")
    
    if len(entries) == 0 :
        print("No items found")
        scraping = False
        return
    
    toggle_detailed_break_up_section(driver)

    
    # No of hospitals under selected category and dsitrct
    print(str(len(entries)) + " items fetched.")

    # Iterate through the entried and print the details
    for ei,e in enumerate(entries):
        
    #     print(ei)
        print("Name : {}".format(e.find_element_by_xpath(".//h5").text))
        print("Address : {}".format(e.find_element_by_xpath("(.//div/div/div)[1]").text))
        print("Phoneno : {}".format(MobileCleanData(e.find_element_by_xpath("(.//div/div/div)[2]//a").text)[1][0]))
        print("Total Beds : {}".format(e.find_element_by_xpath(".//div[2]/div[1]/div[4]/div/ul/li[1]/h3").text))
        print("Available Beds : {}".format(e.find_element_by_xpath(".//div[2]/div[1]/div[4]/div/ul/li[2]/h3").text))
        print("Verified On : {}".format(e.find_element_by_xpath(".//div[3]/small").text))
        print("------------------------")
        bed_categories = e.find_elements_by_xpath(".//div[2]/div[2]/div[2]/div/div")
        print("Categories of beds : {}".format(len(bed_categories)))
        for bc in bed_categories:
            # Make sure you have click on "View detailed Details" else you will get blank details
            try:
                print("Category : {}".format(bc.find_element_by_xpath(".//div/div[1]").text))
                print("Available : {}".format(bc.find_element_by_xpath(".//div/div[2]/div/div[4]/div/ul/li[2]/h3").text))
                print("Total : {}".format(bc.find_element_by_xpath(".//div/div[2]/div/div[4]/div/ul/li[1]/h3").text))
            except:
                print("Due to error skipping the category section")
            print("----category_ end-------\n")
            
        print("----------END------------")
    scraping = False

def still_loading(driver,wait):
    try:
        return driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_upPgo"]').value_of_css_property("display")
    except:
        return "error"

# %%
# List of districts
# district_list = driver.find_element_by_id("ctl00_ContentPlaceHolder1_ddl_District")
# final_district_list = []
# for i in district_list.text.split("\n")[1:-1]:
#     final_district_list.append(i.strip())

# %%
# Options Radio Buttons
# RADIO_BUTTONS = driver.find_elements_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_rdo_Govt_Flag']/label")
# for i,j in enumerate(RADIO_BUTTONS):
#     print(j.text,i)

# %% [markdown]
# ## Test Code

# %% [markdown]
# ### Steps one-by-one
# * Call initialize Function > init_scrape
# * First select the hospital type > select_hospital_type
# * Then select district > select_district_and_wait_until_load
# * Get page no > no_of_pages_for_selected_district_and_type
# * Iterate through Pages
#     * Call this function > toggle_detailed_break_up_section
#     * Call scrape data to start scraping > scrape_data

# %%
driver,wait = init_scrape(chrome_options,endpoint)

# %%
for district_lable,district_id in using_district_list.items():
#     print(district_lable,district_id)
    for hospital_type in using_hospital_type:
        select_hospital_type(driver,using_hospital_type[hospital_type]["webkey"])
        select_district_and_wait_until_load(driver,wait,district_lable)
        time.sleep(5)
        no_of_pages = no_of_pages_for_selected_district_and_type(driver)
        global_buggy_pnum = 0
        for pg_no in range(no_of_pages):
            if pg_no != 0 or (pg_no==0 and global_buggy_pnum!=0) :
                while True:
                    if scraping:
                        time.sleep(2)
                    else:
                        global_buggy_pnum = pg_no
                        select_page_pagination_section(driver,pg_no+1)
                        time.sleep(10)
                        break
            
            while still_loading(driver,wait) != "none":
                driver.implicitly_wait(10)
            scrape_data(driver)
        print(f"Exiting from District : {district_lable} Type : {hospital_type} Page No : {pg_no}")
# Out:
# 4 items fetched.
# Name :  Barjora Super Speciality Hospital (Government Hospital)
# Address :   Barjora , BANKURA
# Phoneno : 8509658547
# Total Beds : 180
# Available Beds : 128
# Verified On : Last Updated On : 13/05/2021 02:27 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 123
# Total : 175
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 5
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Name :  Bishnupur Super Speciality Hospital (Government Hospital)
# Address :   4th floor Ward, Bishnhupur SSH. Rasikgang . Pin : 722122 , BANKURA
# Phoneno : 8637836997
# Total Beds : 0
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 10:34 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  COVID Unit BSMCH (Government Hospital)
# Address :   Bankura Medical College , Kenduadihi , BANKURA
# Phoneno : 9434231480
# Total Beds : 100
# Available Beds : 32
# Verified On : Last Updated On : 13/05/2021 09:29 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 18
# Total : 32
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 45
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 6
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 6
# Total : 17
# ----category_ end-------
#
# ----------END------------
# Name :  ONDA SUPER SPECIALITY HOSPITAL (Government Hospital)
# Address :   KUSHTE , ONDA BLOCK PINCODE : 722144 , BANKURA
# Phoneno : 8350057933
# Total Beds : 220
# Available Beds : 42
# Verified On : Last Updated On : 13/05/2021 12:24 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 42
# Total : 170
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 40
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Exiting from District : BANKURA Type : Government Hospital Page No : 0
# No items found
# Exiting from District : BANKURA Type : Govt. Requisitioned Pvt. Hospital Page No : 0
# 10 items fetched.
# Name :  ADSR New Building (Safe Home)
# Address :   Haripur, Indas, bankura , BANKURA
# Phoneno : 9434754996
# Total Beds : 40
# Available Beds : 30
# Verified On : Last Updated On : 13/05/2021 02:08 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 30
# Total : 40
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Ailakundi PTTI (Safe Home)
# Address :   Behind Bankura SBSTC Bus Stand , BANKURA
# Phoneno : 9434440300
# Total Beds : 30
# Available Beds : 18
# Verified On : Last Updated On : 13/05/2021 07:20 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 18
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  ANAMOY POLYCLINIC DIAGNOSTIC CENTRE HOSPITAL (Private Hospital (Self Run))
# Address :   KENDUADIHI, BANKURA , BANKURA
# Phoneno : 9732319959
# Total Beds : 11
# Available Beds : 7
# Verified On : Last Updated On : 12/05/2021 05:42 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 5
# Total : 8
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 2
# Total : 3
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Bagdiha BJRCY Hostel (Safe Home)
# Address :   Bagdiha, Indpur , BANKURA
# Phoneno : 7063017340
# Total Beds : 27
# Available Beds : 26
# Verified On : Last Updated On : 13/05/2021 11:50 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 26
# Total : 27
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Banabitan Lodge (Safe Home)
# Address :   Joypur, Bankura , BANKURA
# Phoneno : 9641599486
# Total Beds : 23
# Available Beds : 5
# Verified On : Last Updated On : 13/05/2021 02:05 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 5
# Total : 23
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  BANKURA NURSING HOME (Private Hospital (Self Run))
# Address :   PATPUR BANKURA , BANKURA
# Phoneno : 9564280791
# Total Beds : 16
# Available Beds : 1
# Verified On : Last Updated On : 13/05/2021 10:48 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 1
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  BANKURA SEVA NIKETAN HOSPITAL (Private Hospital (Self Run))
# Address :   PATPUR, JAIL ROAD, BANKURA , BANKURA
# Phoneno : 7797701790
# Total Beds : 35
# Available Beds : 2
# Verified On : Last Updated On : 13/05/2021 12:36 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 34
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  CCRD (Safe Home)
# Address :   Panchmura , BANKURA
# Phoneno : 7001215610
# Total Beds : 20
# Available Beds : 13
# Verified On : Last Updated On : 13/05/2021 11:28 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 13
# Total : 20
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  CURE HOSPITAL (Private Hospital (Self Run))
# Address :   LOKEPUE, KENDUADIHI, BANKURA 722102 , BANKURA
# Phoneno : 9732512000
# Total Beds : 16
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 09:13 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Dhansimla Bidyabhaban Hostel (Safe Home)
# Address :   Dhansimla, Sonamukhi , BANKURA
# Phoneno : 9749815197
# Total Beds : 20
# Available Beds : 20
# Verified On : Last Updated On : 13/05/2021 12:54 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 16
# Total : 16
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 4
# Total : 4
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# 10 items fetched.
# Name :  Dhenkikata Integrated Govt. School (Safe Home)
# Address :   Dhenkikata, Mandalkuli GP , BANKURA
# Phoneno : 8013470758
# Total Beds : 52
# Available Beds : 24
# Verified On : Last Updated On : 13/05/2021 11:22 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 24
# Total : 52
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  DISHA MULTISPECIALITY HOSPITAL (Private Hospital (Self Run))
# Address :   251, COLLEGE ROAD, BISHNUPUR, PIN-722122 , BANKURA
# Phoneno : 9883592131
# Total Beds : 24
# Available Beds : 13
# Verified On : Last Updated On : 13/05/2021 12:19 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 10
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 3
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Glocal Hospital Sonamukhi a unit of Glocal Healthcare Systems Private Limited (Private Hospital (Self Run))
# Address :   GANGADI NAGAR, BANKUR TO BURDWAN ROAD, SONAMUKHI , BANKURA
# Phoneno : 9830202195
# Total Beds : 69
# Available Beds : 69
# Verified On : Last Updated On : 13/05/2021 01:03 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 14
# Total : 14
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 30
# Total : 30
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 20
# Total : 20
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 4
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 1
# Total : 1
# ----category_ end-------
#
# ----------END------------
# Name :  HARDIK MEDICAL DIAGONOSTIC CENTRE PVT.LTD. (Private Hospital (Self Run))
# Address :   442/3, RABINDRA SARANI, BANKURA MNC , BANKURA
# Phoneno : 8373082080
# Total Beds : 10
# Available Beds : 0
# Verified On : Last Updated On : 12/05/2021 05:41 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  JEEBAN SURAKSHA HOSPITAL PVT.LTD (Private Hospital (Self Run))
# Address :   KATJURI DANGA, CHHATNA ROAD, BANKURA , BANKURA
# Phoneno : 8617560711
# Total Beds : 52
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 12:37 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 41
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 3
# ----category_ end-------
#
# ----------END------------
# Name :  Kuraria Karmatirtha (Safe Home)
# Address :   Kuraria, Bikna, Bankura , BANKURA
# Phoneno : 8370861243
# Total Beds : 50
# Available Beds : 45
# Verified On : Last Updated On : 12/05/2021 04:48 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 45
# Total : 50
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Lalgarh Safe Home (Safe Home)
# Address :   Lalgarh, Bishnupur , BANKURA
# Phoneno : 7586967479
# Total Beds : 30
# Available Beds : 22
# Verified On : Last Updated On : 12/05/2021 04:00 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 22
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  MAA MAHAMAYA HOSPITAL (Private Hospital (Self Run))
# Address :   KENDUADIHI, BANKURA , BANKURA
# Phoneno : 8145757511
# Total Beds : 10
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 01:36 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 2
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# ----------END------------
# Name :  MTPS (Safe Home)
# Address :   Durlavpur , BANKURA
# Phoneno : 7602053632
# Total Beds : 15
# Available Beds : 15
# Verified On : Last Updated On : 13/05/2021 01:41 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 13
# Total : 13
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 2
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Onda Stadium (Safe Home)
# Address :   Onda, Bankura , BANKURA
# Phoneno : 6295595366
# Total Beds : 10
# Available Beds : 8
# Verified On : Last Updated On : 13/05/2021 12:18 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 7
# Total : 9
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 1
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# 5 items fetched.
# Name :  Saltora Auditorium Cum Marriage Hall (Safe Home)
# Address :   Saltora , BANKURA
# Phoneno : 8116295850
# Total Beds : 20
# Available Beds : 20
# Verified On : Last Updated On : 13/05/2021 02:04 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 18
# Total : 18
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 2
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  SIBANI SEVA NIKETAN PVT LTD (Private Hospital (Self Run))
# Address :   KATJURI DANGA, KENDUADIHI, BANKURA , BANKURA
# Phoneno : 8373085100
# Total Beds : 2
# Available Beds : 2
# Verified On : Last Updated On : 13/05/2021 08:59 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 2
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Simlapal Khaadi Bhaban (Safe Home)
# Address :   Jagannathpur, Simlapal, Bankura , BANKURA
# Phoneno : 7001363490
# Total Beds : 20
# Available Beds : 20
# Verified On : Last Updated On : 13/05/2021 12:08 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 10
# Total : 10
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 10
# Total : 10
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Sonamukhi Municipality Safe Home (Safe Home)
# Address :   Sonamukhi , BANKURA
# Phoneno : 7029521965
# Total Beds : 40
# Available Beds : 29
# Verified On : Last Updated On : 13/05/2021 12:56 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 25
# Total : 36
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 4
# Total : 4
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Susunia Krishak Bazar (Safe Home)
# Address :   Susunia, Chhatna , BANKURA
# Phoneno : 6294514242
# Total Beds : 30
# Available Beds : 26
# Verified On : Last Updated On : 13/05/2021 09:49 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 26
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Exiting from District : BANKURA Type : Private Hospital Page No : 2
# 4 items fetched.
# Name :  COVID HOSPITAL SSH SURI (Government Hospital)
# Address :   Suri Sadar hospital , BIRBHUM
# Phoneno : 9434220944
# Total Beds : 200
# Available Beds : 200
# Verified On : Last Updated On : 13/05/2021 01:15 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 170
# Total : 170
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 15
# Total : 15
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 15
# Total : 15
# ----category_ end-------
#
# ----------END------------
# Name :  Night Shelter at SURI DH (Government Hospital)
# Address :   SURI DH , BIRBHUM
# Phoneno : 9475035111
# Total Beds : 50
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 10:54 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  RAMPURHAT GOVT MEDICAL COLLEGE AND HOSPITAL (Government Hospital)
# Address :   HOSPITAL MORE, RAMPURHAT,PIN-731224 , BIRBHUM
# Phoneno : 9330980945
# Total Beds : 240
# Available Beds : 109
# Verified On : Last Updated On : 13/05/2021 01:10 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 83
# Total : 148
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 25
# Total : 80
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 1
# Total : 12
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  SURI SADAR HOSPITAL, NTS SAFE HOME (Government Hospital)
# Address :   SURI, BURBHUM , BIRBHUM
# Phoneno : 9434220944
# Total Beds : 50
# Available Beds : 39
# Verified On : Last Updated On : 13/05/2021 01:51 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 39
# Total : 50
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Exiting from District : BIRBHUM Type : Government Hospital Page No : 0
# 1 items fetched.
# Name :  GLOCAL HOSPITAL (Govt. Requisitioned Pvt. Hospital)
# Address :   Nanoor Chandidas Rd, Khosh Kadambapur, West Bengal 731204 , BIRBHUM
# Phoneno : 7063584842
# Total Beds : 90
# Available Beds : 32
# Verified On : Last Updated On : 13/05/2021 02:13 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 32
# Total : 45
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 35
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# ----------END------------
# Exiting from District : BIRBHUM Type : Govt. Requisitioned Pvt. Hospital Page No : 0
# 4 items fetched.
# Name :  Ambua Govt. Model School (Safe Home)
# Address :   Ambua,Murarai,Pin-731222 , BIRBHUM
# Phoneno : 8436548938
# Total Beds : 100
# Available Beds : 97
# Verified On : Last Updated On : 13/05/2021 02:53 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 97
# Total : 100
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  CMOH OFFICE SAFE HOME (Safe Home)
# Address :   Old outdoor Campus,Suri, West Bengal 731101 , BIRBHUM
# Phoneno : 7363092304
# Total Beds : 30
# Available Beds : 23
# Verified On : Last Updated On : 13/05/2021 10:54 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 23
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Niramoy TB Sanatorium Safe Home (Safe Home)
# Address :   Dubrajpur , West Bengal 731123 , BIRBHUM
# Phoneno : 7908081168
# Total Beds : 150
# Available Beds : 111
# Verified On : Last Updated On : 13/05/2021 01:51 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 105
# Total : 142
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 6
# Total : 8
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  West Bengal Comprehensive Area Development Corporation -CDAC (Safe Home)
# Address :   Office of the CADC, Nalhati Word No. 14, PO-Nalhati , PS- Nalhati, Pin No. 731220 , BIRBHUM
# Phoneno : 9800584680
# Total Beds : 40
# Available Beds : 33
# Verified On : Last Updated On : 13/05/2021 02:54 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 33
# Total : 40
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Exiting from District : BIRBHUM Type : Private Hospital Page No : 0
# 5 items fetched.
# Name :  COOCHBEHAR POLICE HOSPITAL (Government Hospital)
# Address :   COOCHBEHAR , COOCHBEHAR
# Phoneno : 8670544844
# Total Beds : 20
# Available Beds : 17
# Verified On : Last Updated On : 13/05/2021 10:32 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 17
# Total : 20
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  DINHATA SUB DIVISIONAL HOSPITAL (Government Hospital)
# Address :   DINHATA MAIN ROAD , COOCHBEHAR
# Phoneno : 8436789565
# Total Beds : 36
# Available Beds : 11
# Verified On : Last Updated On : 13/05/2021 10:58 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 24
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 9
# Total : 12
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  MAHARAJA JITENDRA NARAYAN MEDICAL COLLEGE HOSPITAL (Government Hospital)
# Address :   SUNITY ROAD COOCHBEHAR , COOCHBEHAR
# Phoneno : 7605041535
# Total Beds : 90
# Available Beds : 16
# Verified On : Last Updated On : 13/05/2021 12:07 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 3
# Total : 27
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 13
# Total : 53
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# ----------END------------
# Name :  MATHABHANGA SUB DIVISIONAL HOSPITAL (Government Hospital)
# Address :   MATHABHANGA , COOCHBEHAR
# Phoneno : 9641363961
# Total Beds : 23
# Available Beds : 16
# Verified On : Last Updated On : 13/05/2021 10:15 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 16
# Total : 23
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  TUFANGANJ MENTAL HOSPITAL (Government Hospital)
# Address :   TUFANGANJ , COOCHBEHAR
# Phoneno : 9614142551
# Total Beds : 200
# Available Beds : 194
# Verified On : Last Updated On : 13/05/2021 10:30 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 194
# Total : 200
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Exiting from District : COOCHBEHAR Type : Government Hospital Page No : 0
# No items found
# Exiting from District : COOCHBEHAR Type : Govt. Requisitioned Pvt. Hospital Page No : 0
# 9 items fetched.
# Name :  Babu Jagjivanram Kendriya Chatri Niwas (Safe Home)
# Address :   MATHABHANGA , COOCHBEHAR
# Phoneno : 9933639827
# Total Beds : 56
# Available Beds : 56
# Verified On : Last Updated On : 13/05/2021 10:46 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 56
# Total : 56
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Cooch behar Mission Hospital (Private Hospital (Self Run))
# Address :   Chakchaka, Cooch Behar , COOCHBEHAR
# Phoneno : 9832514641
# Total Beds : 30
# Available Beds : 11
# Verified On : Last Updated On : 13/05/2021 01:45 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 3
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 8
# Total : 10
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  COOCHBEHAR NETAJI INDOOR STADIUM SAFE HOME (Safe Home)
# Address :   COOCHBEHAR , COOCHBEHAR
# Phoneno : 9834144980
# Total Beds : 130
# Available Beds : 89
# Verified On : Last Updated On : 13/05/2021 10:03 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 89
# Total : 130
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Haldibari Hospital New Building (Safe Home)
# Address :   HALDIBARI , COOCHBEHAR
# Phoneno : 8900344094
# Total Beds : 20
# Available Beds : 19
# Verified On : Last Updated On : 13/05/2021 10:43 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 19
# Total : 20
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Karola Community Hall (Safe Home)
# Address :   DINHATA II , COOCHBEHAR
# Phoneno : 8116641321
# Total Beds : 30
# Available Beds : 30
# Verified On : Last Updated On : 13/05/2021 10:47 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 30
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Mekhliganj Bus Terminus Building (Safe Home)
# Address :   MEKLIGANJ , COOCHBEHAR
# Phoneno : 9830203174
# Total Beds : 30
# Available Beds : 21
# Verified On : Last Updated On : 13/05/2021 11:42 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 21
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  P K SAHA NURSING HOME (Private Hospital (Self Run))
# Address :   Bairagi Dighi Bye Lane Cooch Behar , COOCHBEHAR
# Phoneno : 7797863330
# Total Beds : 70
# Available Beds : 20
# Verified On : Last Updated On : 13/05/2021 12:35 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 12
# Total : 17
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 4
# Total : 44
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 4
# Total : 9
# ----category_ end-------
#
# ----------END------------
# Name :  Subham Hospital Diagnostic Centre Pvt. Ltd (Private Hospital (Self Run))
# Address :   Cooch Behar Municipality , COOCHBEHAR
# Phoneno : 9832464295
# Total Beds : 20
# Available Beds : 3
# Verified On : Last Updated On : 13/05/2021 12:48 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 3
# Total : 4
# ----category_ end-------
#
# ----------END------------
# Name :  Tufanganj Polytechnic College (Safe Home)
# Address :   TUFANGANJ , COOCHBEHAR
# Phoneno : 8972050757
# Total Beds : 100
# Available Beds : 100
# Verified On : Last Updated On : 13/05/2021 11:09 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 100
# Total : 100
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Exiting from District : COOCHBEHAR Type : Private Hospital Page No : 0
# 5 items fetched.
# Name :  Baruipur COVID Hospital (Government Hospital)
# Address :   Baruipur Municipality, South 24 Parganas , DAKSHIN 24 PARGANA
# Phoneno : 9432582068
# Total Beds : 100
# Available Beds : 2
# Verified On : Last Updated On : 13/05/2021 02:27 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 100
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  CANNING COVID HOSPITAL (Government Hospital)
# Address :   Canning Sports Complex Canning-I Block , DAKSHIN 24 PARGANA
# Phoneno : 9800374819
# Total Beds : 108
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 02:07 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 48
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 55
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Name :  DIAMOND HARBOUR GOVERNMENT MEDICAL COLLEGE AND HOSPITAL (Government Hospital)
# Address :   Diamond Harbour , DAKSHIN 24 PARGANA
# Phoneno : 7797118955
# Total Beds : 150
# Available Beds : 22
# Verified On : Last Updated On : 13/05/2021 01:31 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 22
# Total : 135
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 1
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Name :  K. S. ROY T B HOSPITAL (Government Hospital)
# Address :   Jadavpur Kolkata , DAKSHIN 24 PARGANA
# Phoneno : 9903966397
# Total Beds : 130
# Available Beds : 2
# Verified On : Last Updated On : 13/05/2021 02:40 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 130
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  KAKDWIP SUPERSPECIALITY HOSPITAL (Government Hospital)
# Address :   KAKDWIP , DAKSHIN 24 PARGANA
# Phoneno : 8348670855
# Total Beds : 40
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 03:04 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 36
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Exiting from District : DAKSHIN 24 PARGANA Type : Government Hospital Page No : 0
# No items found
# Exiting from District : DAKSHIN 24 PARGANA Type : Govt. Requisitioned Pvt. Hospital Page No : 0
# 10 items fetched.
# Name :  AMTALA TRAUMA CARE SAFE HOME (Safe Home)
# Address :   Bishnupur II Block , DAKSHIN 24 PARGANA
# Phoneno : 9903714512
# Total Beds : 45
# Available Beds : 5
# Verified On : Last Updated On : 13/05/2021 02:08 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 5
# Total : 37
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 8
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Baruipur Kisan Mandi (Safe Home)
# Address :   Vill+Post: Sitakundu, PS: Baruipur, , DAKSHIN 24 PARGANA
# Phoneno : 8584030061
# Total Beds : 50
# Available Beds : 12
# Verified On : Last Updated On : 13/05/2021 01:24 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 7
# Total : 35
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 5
# Total : 15
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  BHARAT SEVASRAM SANGHA HOSPITAL (Private Hospital (Self Run))
# Address :   D.H.ROAD, JOKA , DAKSHIN 24 PARGANA
# Phoneno : 9073368550
# Total Beds : 25
# Available Beds : 4
# Verified On : Last Updated On : 13/05/2021 01:54 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 2
# Total : 16
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 2
# Total : 7
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 2
# ----category_ end-------
#
# ----------END------------
# Name :  BHOGALI KARMATIRTHA (Safe Home)
# Address :   Bhogali-I GP, Bhangore-II Block , DAKSHIN 24 PARGANA
# Phoneno : 9832144299
# Total Beds : 50
# Available Beds : 5
# Verified On : Last Updated On : 13/05/2021 01:13 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 5
# Total : 46
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  DIAMOND HARBOUR SAFE HOME (Safe Home)
# Address :   SDO GROUND, DIAMOND HARBOUR , DAKSHIN 24 PARGANA
# Phoneno : 3174256475
# Total Beds : 100
# Available Beds : 32
# Verified On : Last Updated On : 13/05/2021 02:58 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 32
# Total : 100
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  INDIAN INSTITUTE OF LIVER AND DIGESTIVE SCIENCES (Private Hospital (Self Run))
# Address :   MALIPUKURIA, JAGADISHPUR, SONARPUR , DAKSHIN 24 PARGANA
# Phoneno : 3324342300
# Total Beds : 25
# Available Beds : 4
# Verified On : Last Updated On : 13/05/2021 03:10 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 4
# Total : 20
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 5
# ----category_ end-------
#
# ----------END------------
# Name :  ISPAT COOPERATIVE HOSPITAL (Private Hospital (Self Run))
# Address :   P.O.+VILL. - KALIKAPUR, P.S. - SONARPUR , DAKSHIN 24 PARGANA
# Phoneno : 8001257528
# Total Beds : 59
# Available Beds : 16
# Verified On : Last Updated On : 13/05/2021 01:58 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ...
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  New Niramaya Nursing Home (Private Hospital (Self Run))
# Address :   115/A, Basudebpur Road, Arambagh , HOOGHLY
# Phoneno : 9933358680
# Total Beds : 10
# Available Beds : 2
# Verified On : Last Updated On : 13/05/2021 10:04 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 1
# Total : 5
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 5
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  New United Nursing Home (Private Hospital (Self Run))
# Address :   230, D C R ROAD, CHANDANNAGAR, CHANDANNAGAR , HOOGHLY
# Phoneno : 3326830020
# Total Beds : 40
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:26 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 30
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 4
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 6
# ----category_ end-------
#
# ----------END------------
# Name :  Pandey sebayan Nursing Home (Private Hospital (Self Run))
# Address :   Barasat, Chakraborty Para, Chandannagar , HOOGHLY
# Phoneno : 9432804180
# Total Beds : 5
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:08 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 5
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# 10 items fetched.
# Name :  Pandua Karmatirtha (Safe Home)
# Address :   Pandua, Hooghly , HOOGHLY
# Phoneno : 7605059328
# Total Beds : 44
# Available Beds : 32
# Verified On : Last Updated On : 13/05/2021 11:43 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 31
# Total : 42
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 1
# Total : 2
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Rishra Seva Sadan (Safe Home)
# Address :   1, Keshub Chandra Sen Rd, Rishra, Hooghly, West Bengal 712250 , HOOGHLY
# Phoneno : 7605059328
# Total Beds : 36
# Available Beds : 21
# Verified On : Last Updated On : 13/05/2021 02:47 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 21
# Total : 36
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Ruplal Nandy Memorial Cancer Research Centre (Safe Home)
# Address :   Sarishapara, Chandannagar, West Bengal 712136 , HOOGHLY
# Phoneno : 7605059328
# Total Beds : 35
# Available Beds : 23
# Verified On : Last Updated On : 13/05/2021 07:32 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 18
# Total : 30
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 5
# Total : 5
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  S.E. Nursing Home (Private Hospital (Self Run))
# Address :   473, Banepukur Road, Arambagh, Arambagh, Arambagh , HOOGHLY
# Phoneno : 8617057275
# Total Beds : 10
# Available Beds : 9
# Verified On : Last Updated On : 13/05/2021 10:25 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 9
# Total : 10
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Sanyukta Healthcare Unit (Private Hospital (Self Run))
# Address :   373/A, BASANTAPUR MORE, ARAMBAGH, ARAMBAGH , HOOGHLY
# Phoneno : 9775569936
# Total Beds : 20
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 10:08 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 10
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Seven Rangers Healthcare Pvt Ltd (Private Hospital (Self Run))
# Address :   Durgapur Expy, Gobra Crossing, near Toll Plaza, Dankuni, West Bengal 712310 , HOOGHLY
# Phoneno : 7605059328
# Total Beds : 20
# Available Beds : 20
# Verified On : Last Updated On : 13/05/2021 10:33 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 5
# Total : 5
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 13
# Total : 13
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 2
# Total : 2
# ----category_ end-------
#
# ----------END------------
# Name :  Sramajibi Hospital (Private Hospital (Self Run))
# Address :   Road Number 31, Milki Badamtola, West Bengal 712223 , HOOGHLY
# Phoneno : 7605059328
# Total Beds : 62
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:26 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 40
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 14
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 8
# ----category_ end-------
#
# ----------END------------
# Name :  Tarakeswar Safe Home (Safe Home)
# Address :   Motel, Near Pearl's Rozarie School, Tarakeswar, Hooghly, West Bengal 712403 , HOOGHLY
# Phoneno : 7605059328
# Total Beds : 60
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 01:13 PM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 40
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Vikdas Godown (Safe Home)
# Address :   Goghat, Hooghly , HOOGHLY
# Phoneno : 7605059328
# Total Beds : 70
# Available Beds : 70
# Verified On : Last Updated On : 13/05/2021 11:15 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 50
# Total : 50
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 20
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Name :  Village Healthcare (Private Hospital (Self Run))
# Address :   BARIZHATI, CHANDITALA, CHANDITALA, CHANDITALA , HOOGHLY
# Phoneno : 9903040481
# Total Beds : 37
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 09:58 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 9
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 12
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 10
# ----category_ end-------
#
# ----------END------------
# 1 items fetched.
# Name :  We Care Hospital (Private Hospital (Self Run))
# Address :   101/1/Z/Z/M, R.S. VERMA ROAD, UTTARPARA , HOOGHLY
# Phoneno : 3326643456
# Total Beds : 26
# Available Beds : 0
# Verified On : Last Updated On : 13/05/2021 11:20 AM
# ------------------------
# Categories of beds : 5
# Category : Covid Beds (Regular)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : Covid Beds with Oxygen Support
# Available : 0
# Total : 20
# ----category_ end-------
#
# Category : HDU Beds (Covid)
# Available : 0
# Total : 6
# ----category_ end-------
#
# Category : CCU Beds (Covid - without ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# Category : CCU Beds (Covid - with ventilator)
# Available : 0
# Total : 0
# ----category_ end-------
#
# ----------END------------
# Exiting from District : HOOGHLY Type : Private Hospital Page No : 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-fe21a99c1b58> in no_of_pages_for_selected_district_and_type(driver)
#      95     try:
# ---> 96         pages=len(driver.find_elements_by_xpath("//*[@id='ctl00_ContentPlaceHolder1_GridView2']/tbody/tr[1]/td/table/tbody/tr/td"))
#      97         if pages == 0:
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_elements_by_xpath(self, xpath)
#     409         """
# --> 410         return self.find_elements(by=By.XPATH, value=xpath)
#     411
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_elements(self, by, value)
#    1004         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1005         return self.execute(Command.FIND_ELEMENTS, {
#    1006             'using': by,
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~/anaconda3/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-73-82bb92b668f5> in <module>
#       5         select_district_and_wait_until_load(driver,wait,district_lable)
#       6         time.sleep(5)
# ----> 7         no_of_pages = no_of_pages_for_selected_district_and_type(driver)
#       8         global_buggy_pnum = 0
#       9         for pg_no in range(no_of_pages):
#
# <ipython-input-65-fe21a99c1b58> in no_of_pages_for_selected_district_and_type(driver)
#      99         return pages
#     100     except:
# --> 101         raise Exception("ERROR : Can't get number of pages for selected district and type")
#     102
#     103 # Select page
#
# Exception: ERROR : Can't get number of pages for selected district and type

# %%
# select_district_and_wait_until_load(driver,wait,"BANKURA")
# select_hospital_type(driver,3)
# no_of_pages = no_of_pages_for_selected_district_and_type(driver)
# print(no_of_pages)
# global_buggy_pnum = 0
# for pg_no in range(no_of_pages):
#     print(f"\nGoing on page {pg_no+1}\n")
#     if pg_no != 0 :
#         global_buggy_pnum = pg_no
#         select_page_pagination_section(driver,pg_no+1)
#         toggle_detailed_break_up_section(driver)

#     toggle_detailed_break_up_section(driver)
#     scrape_data(driver)
# print(f"Exiting from District : {district_lable} Type : {hospital_type} Page No : {pg_no}")

# %%
# select_district_and_wait_until_load(driver,wait,"BANKURA")
# select_hospital_type(driver,2)
# # select_page_pagination_section(driver,3)
# scrape_data(driver)

# %%
# !git add .
# !git commit -m "update"
# !git push origin main
# Out:
# [main e7a24b9] update
#  2 files changed, 4476 insertions(+), 120 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 16.47 KiB | 1.18 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:Covidsupport-live/Data-Cleaninng-Scripts.git
#    7d76f29..e7a24b9  main -> main
